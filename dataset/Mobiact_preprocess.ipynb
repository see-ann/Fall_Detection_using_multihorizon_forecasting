# %%
import pandas as pd
import os
from tqdm.notebook import tqdm
# Out:
# /var/folders/jg/47v2cmwn6bx5mnmlt0lbg_pw0000gn/T/ipykernel_13030/3926211839.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
file = open('MobiAct_Dataset_v2.0/Readme.txt', 'r', encoding='latin1')
strings = file.readlines()
file.close()
for s in strings:
    print(s)
# Out:
# ====================================================================
#
# ===========================MobiActDataset===========================
#
# The NEW version of the MobiAct dataset includes:
#
#  	Four different types of falls performed by 66 participants
#
#  	Eleven different types of ADLs performed by 19 participants and nine types of ADLs performed by 59 participants (plus one activity "LYI" which results from the inactivity period after a fall by 66 participants)
#
#  	Five sub-scenarios which construct one scenario of daily living, which consists of a sequence of 50 activities and performed by 19 participants.
#
#
#
# The new released version of the MobiAct dataset includes:
#
#   The raw recorded data in txt format, separated by each activity
#
#   The annotated data in csv format, separated by each activity
#
#
#
#
#
# Filename format:
#
# <ADL OR FALL OR SCENARIO_CODE>_<SENSOR_CODE>_<SUBJECT_ID>_<TRIAL_NO>.txt
#
#
#
# examples:
#
# 1 -->	WAL_acc_5_1.txt
#
# 2 -->	STD_ori_9_5.txt
#
# 3 -->	FKL_gyro_3_2.txt
#
# 4 -->	SRH_acc_1_1.txt
#
#
#
#
#
# Subjects:
#
# +------+---------+-----------+-------+----------+----------+----------+
#
# |  ID  |  Name   |  Surname  |  Age  |  Height  |  Weight  |  Gender  |
#
# +------+---------+-----------+-------+----------+----------+----------+
#
# |    1 | sub1    | sub1      |    32 |      180 |       85 |  M       |
#
# |    2 | sub2    | sub2      |    26 |      169 |       64 |  M       |
#
# |    3 | sub3    | sub3      |    26 |      164 |       55 |  F       |
#
# |    4 | sub4    | sub4      |    32 |      186 |       93 |  M       |
#
# |    5 | sub5    | sub5      |    36 |      160 |       50 |  F       |
#
# |    6 | sub6    | sub6      |    22 |      172 |       62 |  F       |
#
# |    7 | sub7    | sub7      |    25 |      189 |       80 |  M       |
#
# |    8 | sub8    | sub8      |    22 |      183 |       93 |  M       |
#
# |    9 | sub9    | sub9      |    30 |      177 |      102 |  M       |
#
# |   10 | sub10   | sub10     |    26 |      170 |       90 |  F       |
#
# |   11 | sub11   | sub11     |    26 |      168 |       80 |  F       |
#
# |   12 | sub12   | sub12     |    29 |      178 |       83 |  M       |
#
# |   13 | sub13   | sub13     |    24 |      177 |       62 |  M       |
#
# |   14 | sub14   | sub14     |    24 |      178 |       85 |  M       |
#
# |   15 | sub15   | sub15     |    25 |      173 |       82 |  M       |
#
# |   16 | sub16   | sub16     |    27 |      172 |       56 |  F       |
#
# |   17 | sub17   | sub17     |    25 |      173 |       67 |  M       |
#
# |   18 | sub18   | sub18     |    25 |      176 |       73 |  M       |
#
# |   19 | sub19   | sub19     |    25 |      161 |       63 |  F       |
#
# |   20 | sub20   | sub20     |    26 |      178 |       71 |  M       |
#
# |   21 | sub21   | sub21     |    25 |      180 |       70 |  M       |
#
# |   22 | sub22   | sub22     |    22 |      187 |       90 |  M       |
#
# |   23 | sub23   | sub23     |    23 |      171 |       64 |  M       |
#
# |   24 | sub24   | sub24     |    21 |      193 |      112 |  M       |
#
# |   25 | sub25   | sub25     |    22 |      170 |       62 |  F       |
#
# |   26 | sub26   | sub26     |    25 |      163 |       60 |  F       |
#
# |   27 | sub27   | sub27     |    25 |      180 |       82 |  M       |
#
# |   28 | sub28   | sub28     |    23 |      178 |       70 |  Ì       |
#
# |   29 | sub29   | sub29     |    27 |      186 |      103 |  M       |
#
# |   30 | sub30   | sub30     |    47 |      172 |       90 |  M       |
#
# |   31 | sub31   | sub31     |    27 |      170 |       75 |  M       |
#
# |   32 | sub32   | sub32     |    25 |      190 |       77 |  M       |
#
# |   33 | sub33   | sub33     |    27 |      171 |       70 |  M       |
#
# |   34 | sub34   | sub34     |    24 |      175 |       85 |  Ì       |
#
# |   35 | sub35   | sub35     |    23 |      181 |       76 |  M       |
#
# |   36 | sub36   | sub36     |    22 |      164 |       62 |  F       |
#
# |   37 | sub37   | sub37     |    25 |      172 |       63 |  M       |
#
# |   38 | sub38   | sub38     |    21 |      170 |       88 |  F       |
#
# |   39 | sub39   | sub39     |    26 |      174 |       79 |  M       |
#
# |   40 | sub40   | sub40     |    23 |      178 |       95 |  M       |
#
# |   41 | sub41   | sub41     |    20 |      172 |       67 |  F       |
#
# |   42 | sub42   | sub42     |    22 |      173 |       73 |  M       |
#
# |   43 | sub43   | sub43     |    24 |      179 |       80 |  M       |
#
# |   44 | sub44   | sub44     |    25 |      176 |       80 |  M       |
#
# |   45 | sub45   | sub45     |    26 |      175 |       92 |  M       |
#
# |   46 | sub46   | sub46     |    23 |      175 |       68 |  F       |
#
# |   47 | sub47   | sub47     |    21 |      180 |       85 |  M       |
#
# |   48 | sub48   | sub48     |    22 |      180 |       80 |  M       |
#
# |   49 | sub49   | sub49     |    23 |      178 |       75 |  M       |
#
# |   50 | sub50   | sub50     |    23 |      165 |       50 |  F       |
#
# |   51 | sub51   | sub51     |    23 |      171 |       70 |  M       |
#
# |   52 | sub52   | sub52     |    20 |      179 |       79 |  M       |
#
# |   53 | sub53   | sub53     |    27 |      186 |      120 |  M       |
#
# |   54 | sub54   | sub54     |    27 |      164 |       55 |  F       |
#
# |   55 | sub55   | sub55     |    28 |      178 |       78 |  M       |
#
# |   56 | sub56   | sub56     |    29 |      170 |       75 |  M       |
#
# |   57 | sub57   | sub57     |    21 |      187 |       70 |  Ì       |
#
# |   58 | sub58   | sub58     |    21 |      158 |       58 |  F       |
#
# |   59 | sub59   | sub59     |    26 |      175 |       70 |  M       |
#
# |   60 | sub60   | sub60     |    24 |      183 |      107 |  M       |
#
# |   61 | sub61   | sub61     |    24 |      170 |       70 |  M       |
#
# |   62 | sub62   | sub62     |    20 |      180 |       70 |  M       |
#
# |   63 | sub63   | sub63     |    24 |      187 |       85 |  M       |
#
# |   64 | sub64   | sub64     |    26 |      181 |       70 |  M       |
#
# |   65 | sub65   | sub65     |    40 |      170 |      100 |  M       |
#
# |   66 | sub66   | sub66     |    20 |      193 |       83 |  M       |
#
# |   67 | sub67   | sub67     |    23 |      180 |       67 |  M       |
#
# +------+---------+-----------+-------+----------+----------+----------+
#
#
#
#
#
# Activities of Daily Living:
#
# +----+-------+----------------------------+--------+----------+---------------------------------------------------+
#
# | No.| Label | Activity                   | Trials | Duration | Description                                       |
#
# +----+-------+----------------------------+--------+----------+---------------------------------------------------+
#
# | 1  | STD   | Standing                   | 1      | 5min     | Standing with subtle movements                    |
#
# | 2  | WAL   | Walking                    | 1      | 5min     | Normal walking                                    |
#
# | 3  | JOG   | Jogging                    | 3      | 30s      | Jogging                                           |
#
# | 4  | JUM   | Jumping                    | 3      | 30s      | Continuous jumping                                |
#
# | 5  | STU   | Stairs up                  | 6      | 10s      | Stairs up (10 stairs)                             |
#
# | 6  | STN   | Stairs down                | 6      | 10s      | Stairs down (10 stairs)                           |
#
# | 7  | SCH   | Stand to sit(sit on chair) | 6      | 6s       | Transition from standing to sitting               |
#
# | 8  | SIT   | Sitting on chair           | 1      | 1min     | Sitting on a chair with subtle movements          |
#
# | 9  | CHU   | Sit to stand(chair up)     | 6      | 6s       | Transition from sitting to standing               |
#
# | 10 | CSI   | Car-step in                | 6      | 6s       | Step in a car                                     |
#
# | 11 | CSO   | Car-step out               | 6      | 6s       | Step out a car                                    |
#
# | 12 | LYI   | Lying                      | 12     | -        | Activity taken from the lying period after a fall |
#
# +----+-------+----------------------------+--------+----------+---------------------------------------------------+
#
#
#
#
#
# Falls:
#
# +----+-------+--------------------+--------+----------+---------------------------------------------------------+
#
# | No.| Label | Activity           | Trials | Duration | Description                                             |
#
# +----+-------+--------------------+--------+----------+---------------------------------------------------------+
#
# | 10 | FOL   | Forward-lying      | 3      | 10s      | Fall Forward from standing, use of hands to dampen fall |
#
# | 11 | FKL   | Front-knees-lying  | 3      | 10s      | Fall forward from standing, first impact on knees       |
#
# | 12 | BSC   | Back-sitting-chair | 3      | 10s      | Fall backward while trying to sit on a chair            |
#
# | 13 | SDL   | Sideward-lying     | 3      | 10s      | Fall sidewards from standing, bending legs              |
#
# +----+-------+--------------------+--------+----------+---------------------------------------------------------+
#
#
#
# Scenarios:
#
# +---------------------------------------------------------------------------------------------+
#
# | 1st Scenario of Leaving the Home (SLH), Total duration 125 at max (1 trial/participant)   |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | No.| Label | Activity           | Description                                               |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 1  | STD   | Standing           |  The recording starts with the participant standing       |
#
# | 2  | WAL   | Walking            |  outside the door and locking the door. Then walks        |
#
# | 3  | STN   | Stairs down        |  and descent stairs to leave his home. Following, he      |
#
# | 4  | WAL   | Walking            |  riches the parking area where he stands in front of the  |
#
# | 5  | STD   | Standing           |  car, unlocks the lock of the car, opens the door and     |
#
# | 6  | CSI   | Car-step in        |  gets in the car. He remains sited for some seconds,      |
#
# | 7  | SIT   | Sitting on chair   |  then he gets out of the car, closes the door and stands  |
#
# | 8  | CSO   | Car-step out       |  in front of the door to lock the car.                    |
#
# | 9  | STD   | Standing           |                                                           |
#
# +-----+------+--------------------+-----------------------------------------------------------+
#
# | 2nd Scenario of Being at work (SBW), Total duration 185 at max (1 trial/participant)      |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | No.| Label | Activity           | Description                                               |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 1  | STD   | Standing           |  The recording starts with the participant standing       |
#
# | 2  | WAL   | Walking            |  outside the cars door. Then walks from the parking       |
#
# | 3  | STU   | Stairs up          |  area to his work building. He walks and ascent stairs    |
#
# | 4  | WAL   | Walking            |  till he riches his office where he stops in front of the |
#
# | 5  | STD   | Standing           |  door. Once he finds the keys he opens the door, gets     |
#
# | 6  | WAL   | Walking            |  in his office and walks to his chair, where he sits.     |
#
# | 7  | SCH   | Stand to sit       |                                                           |
#
# | 8  | SIT   | Sitting on chair   |                                                           |
#
# +-----+------+--------------------+-----------------------------------------------------------+
#
# | 3rd Scenario of Leaving work (SLW), Total duration 185 at max (1 trial/participant)       |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | No.| Label | Activity           | Description                                               |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 1  | SIT   | Sitting on chair   |  The recording starts with the participant sitting in the |
#
# | 2  | CHU   | Sit to stand       |  chair in his office area. Then he gets up from the       |
#
# | 3  | WAL   | Walking            |  chair, walks to the door and stands outside the office   |
#
# | 4  | STD   | Standing           |  door. Once he find the keys, he lock the door and        |
#
# | 5  | WAL   | Walking            |  walks and descent stairs till he riches the parking      |
#
# | 6  | STN   | Stairs down        |  area. He walks to his car and stands in front of the     |
#
# | 7  | WAL   | Walking            |  car, unlocks the lock of the car, opens the door and     |
#
# | 8  | STD   | Standing           |  gets in the car. He remains sited for some seconds,      |
#
# | 9  | CSI   | Car-step in        |  then he gets out of the car, closes the door and stands  |
#
# | 10 | SIT   | Sitting on chair   |  in front of the door to lock the car.                    |
#
# | 11 | CSO   | Car-step out       |                                                           |
#
# | 12 | STD   | Standing           |                                                           |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 4th Scenario of Being Exercise (SBE), Total duration 125 at max (1 trial/participant)     |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | No.| Label | Activity           | Description                                               |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 1  | STD   | Standing           |  The recording starts with the participant standing in    |
#
# | 2  | WAL   | Walking            |  front of the car. He starts his exercise by walking,     |
#
# | 3  | JOG   | Jogging            |  then starts jogging from some seconds and once again     |
#
# | 4  | WAL   | Walking            |  walking. Then he stops for some seconds to get a         |
#
# | 5  | STD   | Standing           |  breath and he starts jumping and once more he            |
#
# | 6  | JUM   | Jumping            |  standing to relax a little. Finally he walks till his    |
#
# | 7  | STD   | Standing           |  car and stands outside the door.                         |
#
# | 8  | WAL   | Walking            |                                                           |
#
# | 9  | STD   | Standing           |                                                           |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 5th Scenario of Returning at Home (SRH), Total duration 155 at max (1 trial/participant)  |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | No.| Label | Activity           | Description                                               |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
# | 1  | STD   | Standing           |  The recording starts with the participant standing       |
#
# | 2  | CSI   | Car-step in        |  outside the cars door. He unlocks the lock of the car,   |
#
# | 3  | SIT   | Sitting on chair   |  opens the door and gets in the car. He remains sited     |
#
# | 4  | CSO   | Car-step out       |  for some seconds, then he gets out of the car, closes    |
#
# | 5  | STD   | Standing           |  the door and stands in front of the door to lock the     |
#
# | 6  | WAL   | Walking            |  car.  Then walks from the parking area to his home.      |
#
# | 7  | STU   | Stairs up          |  He walks and ascent stairs till riches his home door,    |
#
# | 8  |  WAL  | Walking            |  where he stands to finds the keys. Then he opens the     |
#
# | 9  | STD   | Standing           |  door, gets in his home, walks till a chair and sits.     |
#
# | 10 | WAL   | Walking            |                                                           |
#
# | 11 | SCH   | Stand to sit       |                                                           |
#
# +----+-------+--------------------+-----------------------------------------------------------+
#
#
#
#
#
# Sensors:
#
# +------+---------------+----------------------------------------------------+--------------------------------------------------------------+
#
# | Code | Type          | Values                                             | Description                                                  |
#
# +------+---------------+----------------------------------------------------+--------------------------------------------------------------+
#
# | acc  | accelerometer | timestamp(ns),x,y,z(m/s^2)                         | Acceleration force along the x y z axes (including gravity). |
#
# | gyro | gyroscope     | timestamp(ns),x,y,z(rad/s)                         | Rate of rotation around the x y z axes (Angular velocity).   |
#
# | ori  | orientation   | timestamp(ns),Azimuth,Pitch,Roll(degrees)          | Angle around the z x y axes.                                 |
#
# +------+---------------+----------------------------------------------------+--------------------------------------------------------------+
#
#
#
# Related work:
#
#   Chatzaki C., Pediaditis M., Vavoulas G., Tsiknakis M. (2017)
#
#    Human Daily Activity and Fall Recognition Using a Smartphones Acceleration Sensor.
#
#    In: Rocker C., O'Donoghue J., Ziefle M., Helfert M., Molloy W. (eds)
#
#    Information and Communication Technologies for Ageing Well and e-Health. ICT4AWE 2016.
#
#    Communications in Computer and Information Science, vol 736, pp 100-118.
#
#    Springer, Cham, DOI 10.1007/978-3-319-62704-5_7
#
#
#
#    Chatzaki, C., Pediaditis, M., Vavoulas, G. and Tsiknakis, M.,
#
#     "Estimating normal and abnormal activities using smartphones",
#
#     In Proceedings of the 13th International Conference on Wearable Micro and Nano Technologies for Personalised Health (pHealth),
#
# 	v.224, pp 195-200,29-31 May 2016, Heraklion, Crete, Greece,  DOI:10.3233/978-1-61499-653-8-195
#
#
#
#    Chatzaki Charikleia,
#
# 	"Estimating human activity patterns in dynamic environments based on smart, wearable sensors : a feasibility study",
#
# 	 M.Sc. Thesis , Dept. Informatics Enginnering,Heraklion, Crete, Greece, 2016
#
#
#
#    Vavoulas, G., Chatzaki, C., Malliotakis, T., Pediaditis, M. and Tsiknakis, M.,
#
#     "The MobiAct Dataset: Recognition of Activities of Daily Living using Smartphones",
#
#     In Proceedings of the International Conference on Information and Communication Technologies for Ageing Well and e-Health (ICT4AWE 2016),
#
#     vol. 1, pp 143-151,ISBN: 978-989-758-180-9, DOI: 10.5220/0005792401430151
#
#
#
#    G. Vavoulas, M. Pediaditis, C. Chatzaki, E. G. Spanakis, M. Tsiknakis,
#
#     "The MobiFall Dataset: Fall Detection and Classification with a Smartphone",
#
#     invited publication for the International Journal of Monitoring and Surveillance Technologies Research,
#
#     pp 44-56, 2014, DOI:10.4018/ijmstr.2014010103
#
#
#
#    G. Vavoulas, M. Pediaditis, E. Spanakis, M. Tsiknakis,
#
#     "The MobiFall Dataset: An Initial Evaluation of Fall Detection Algorithms Using Smartphones",
#
# 	6th IEEE International Symposium on Monitoring & Surveillance Research (ISMSR): Healthcare-Bioinformatics,
#
# 	Chania, Greece, 2013, DOI:10.1109/BIBE.2013.6701629
#
#
#
# ====================================================================

# %%
person_list = []
for s in strings:
    if 'sub' in s and '|' in s:
        temp = s.split('|')
        temp = [x.strip() for x in temp]
        if len(temp) == 9:
            person_list.append(temp[3:-1])

activity_list = []
for s in strings:
    if '|' in s:
        temp = s.split('|')
        temp = [x.strip() for x in temp]
        if len(temp) == 8:
            activity_list.append(temp[1:-1])
activity_list
# Out:
# [['No.', 'Label', 'Activity', 'Trials', 'Duration', 'Description'],
#  ['1', 'STD', 'Standing', '1', '5min', 'Standing with subtle movements'],
#  ['2', 'WAL', 'Walking', '1', '5min', 'Normal walking'],
#  ['3', 'JOG', 'Jogging', '3', '30s', 'Jogging'],
#  ['4', 'JUM', 'Jumping', '3', '30s', 'Continuous jumping'],
#  ['5', 'STU', 'Stairs up', '6', '10s', 'Stairs up (10 stairs)'],
#  ['6', 'STN', 'Stairs down', '6', '10s', 'Stairs down (10 stairs)'],
#  ['7',
#   'SCH',
#   'Stand to sit(sit on chair)',
#   '6',
#   '6s',
#   'Transition from standing to sitting'],
#  ['8',
#   'SIT',
#   'Sitting on chair',
#   '1',
#   '1min',
#   'Sitting on a chair with subtle movements'],
#  ['9',
#   'CHU',
#   'Sit to stand(chair up)',
#   '6',
#   '6s',
#   'Transition from sitting to standing'],
#  ['10', 'CSI', 'Car-step in', '6', '6s', 'Step in a car'],
#  ['11', 'CSO', 'Car-step out', '6', '6s', 'Step out a car'],
#  ['12',
#   'LYI',
#   'Lying',
#   '12',
#   '-',
#   'Activity taken from the lying period after a fall'],
#  ['No.', 'Label', 'Activity', 'Trials', 'Duration', 'Description'],
#  ['10',
#   'FOL',
#   'Forward-lying',
#   '3',
#   '10s',
#   'Fall Forward from standing, use of hands to dampen fall'],
#  ['11',
#   'FKL',
#   'Front-knees-lying',
#   '3',
#   '10s',
#   'Fall forward from standing, first impact on knees'],
#  ['12',
#   'BSC',
#   'Back-sitting-chair',
#   '3',
#   '10s',
#   'Fall backward while trying to sit on a chair'],
#  ['13',
#   'SDL',
#   'Sideward-lying',
#   '3',
#   '10s',
#   'Fall sidewards from standing, bending legs']]

# %%
falls = ['FOL', 'FKL', 'BSC', 'SDL']

columns = ['name', 'age', 'height', 'weight', 'gender']
person_info = pd.DataFrame(person_list, columns=columns)

activity_info = pd.DataFrame(activity_list)
activity_info.columns = activity_info.iloc[0]
activity_info = activity_info.drop(0)
activity_info = activity_info.drop(13)
activity_info = activity_info.reset_index(drop=True)
# print(activity_info.columns)
index = activity_info['No.']
activity_info = activity_info.drop(['No.'], axis=1)
activity_info.index = index
activity_info['label_encoded'] = list(range(len(activity_info)))


activity_info
# Out:
# 0   Label                    Activity Trials Duration  \
# No.
# 1     STD                    Standing      1     5min
# 2     WAL                     Walking      1     5min
# 3     JOG                     Jogging      3      30s
# 4     JUM                     Jumping      3      30s
# 5     STU                   Stairs up      6      10s
# 6     STN                 Stairs down      6      10s
# 7     SCH  Stand to sit(sit on chair)      6       6s
# 8     SIT            Sitting on chair      1     1min
# 9     CHU      Sit to stand(chair up)      6       6s
# 10    CSI                 Car-step in      6       6s
# 11    CSO                Car-step out      6       6s
# 12    LYI                       Lying     12        -
# 10    FOL               Forward-lying      3      10s
# 11    FKL           Front-knees-lying      3      10s
# 12    BSC          Back-sitting-chair      3      10s
# 13    SDL              Sideward-lying      3      10s
#
# 0                                          Description  label_encoded
# No.
# 1                       Standing with subtle movements              0
# 2                                       Normal walking              1
# 3                                              Jogging              2
# 4                                   Continuous jumping              3
# 5                                Stairs up (10 stairs)              4
# 6                              Stairs down (10 stairs)              5
# 7                  Transition from standing to sitting              6
# 8             Sitting on a chair with subtle movements              7
# 9                  Transition from sitting to standing              8
# 10                                       Step in a car              9
# 11                                      Step out a car             10
# 12   Activity taken from the lying period after a fall             11
# 10   Fall Forward from standing, use of hands to da...             12
# 11   Fall forward from standing, first impact on knees             13
# 12        Fall backward while trying to sit on a chair             14
# 13          Fall sidewards from standing, bending legs             15

# %%
activity_info.to_csv('mobiact_preprocessed/activity_info.csv')

# %%
data_dir = 'MobiAct_Dataset_v2.0/Annotated Data/'
act_list = os.listdir(data_dir)
print(act_list)
# Out:
# ['CHU', 'FOL', 'CSI', '.DS_Store', 'JOG', 'CSO', 'SBE', 'WAL', 'SBW', 'SLW', 'SIT', 'SCH', 'FKL', 'SRH', 'STD', 'BSC', 'JUM', 'SDL', 'SLH', 'STN', 'STU']

# %%
valid_labels = set(activity_info['Label'].unique())
valid_labels
# Out:
# {'BSC',
#  'CHU',
#  'CSI',
#  'CSO',
#  'FKL',
#  'FOL',
#  'JOG',
#  'JUM',
#  'LYI',
#  'SCH',
#  'SDL',
#  'SIT',
#  'STD',
#  'STN',
#  'STU',
#  'WAL'}

# %%
train = []
valid = []
test = []

for act in tqdm(act_list):
    act_path = os.path.join(data_dir, act)
    if os.path.isdir(act_path):
        file_list = os.listdir(data_dir + act + '/')
        for file in file_list:
            file_names = file.split('_')
            label = file_names[0]

            data = pd.read_csv(data_dir + act + '/' + file)
            person_num = int(file_names[1])

            # Create a dictionary for this row of data
            row_dict = data.to_dict('records')[0]  # Assuming you want the first row of the CSV
            row_dict['label'] = label  # Add label to the dictionary
            row_dict['person_id'] = person_num  # Add person_id to the dictionary

            # Assign the dictionary to the appropriate list based on person_num
            if person_num <= 50:
                train.append(row_dict)
            elif 50 < person_num <= 53:
                valid.append(row_dict)
            else:
                test.append(row_dict)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
# Convert lists of dictionaries to DataFrames
train_df = pd.DataFrame(train)
valid_df = pd.DataFrame(valid)
test_df = pd.DataFrame(test)

# Save DataFrames to CSV
train_df.to_csv('mobiact_preprocessed/train.csv', index=False)
valid_df.to_csv('mobiact_preprocessed/valid.csv', index=False)
test_df.to_csv('mobiact_preprocessed/test.csv', index=False)

train_df
# Out:
#             timestamp  rel_time     acc_x     acc_y     acc_z    gyro_x  \
# 0       4122885402000       0.0  3.238091  8.132329  4.245767  0.049480
# 1      12925658495000       0.0  5.644234  2.868331  7.323824 -0.029932
# 2       1339017530000       0.0 -2.509551 -2.413142  8.886849 -0.035125
# 3      12818065468000       0.0  6.633194  2.808050  6.496608 -0.032681
# 4       3819654863000       0.0  4.071569  6.147542  6.234699  0.028711
# ...               ...       ...       ...       ...       ...       ...
# 2308  132077803519000       0.0  2.767958  9.498256 -0.876147 -0.036041
# 2309    4711383709000       0.0  0.691561  9.836599 -0.390619 -0.680809
# 2310  120363151803000       0.0  6.169228  7.615893 -1.150099  0.036652
# 2311   14123434217000       0.0 -0.732315  9.832258 -0.218083 -0.046120
# 2312    4948791751000       0.0 -1.042938  9.747363 -0.998665  0.029932
#
#         gyro_y    gyro_z     azimuth       pitch       roll label  person_id
# 0    -0.007636 -0.013744  273.736700  -67.593300  16.014387   CHU          6
# 1     0.016188  0.014661  242.944400  -18.781696  17.408410   CHU         45
# 2     0.003665  0.009163  113.365820   16.452131 -17.527372   CHU          1
# 3     0.008552  0.011606  289.385380  -53.364044  23.002990   CHU         45
# 4     0.029322  0.067501  305.671360  -38.619170  29.405220   CHU          3
# ...        ...       ...         ...         ...        ...   ...        ...
# 2308 -0.051007 -0.004887  139.363980  -79.700560   9.542451   STU         23
# 2309  0.287107  0.085521   32.921436  -69.683150  18.517849   STU          7
# 2310 -0.073915  0.015882  299.075160   -5.150481  21.856638   STU         24
# 2311 -0.051007  0.015272  145.627820  -96.355840  -0.153220   STU         47
# 2312 -0.084299  0.013134  147.640270 -101.392426  -0.626197   STU         19
#
# [2313 rows x 13 columns]

# %%
train
# Out:
# [{'timestamp': 4122885402000,
#   'rel_time': 0.0,
#   'acc_x': 3.23809065585065,
#   'acc_y': 8.13232949215994,
#   'acc_z': 4.24576737406899,
#   'gyro_x': 0.049480084,
#   'gyro_y': -0.0076358155,
#   'gyro_z': -0.013744468,
#   'azimuth': 273.7367,
#   'pitch': -67.5933,
#   'roll': 16.014387,
#   'label': 'CHU',
#   'person_id': 6},
#  {'timestamp': 12925658495000,
#   'rel_time': 0.0,
#   'acc_x': 5.64423377684771,
#   'acc_y': 2.86833107852183,
#   'acc_z': 7.32382413614308,
#   'gyro_x': -0.029932396,
#   'gyro_y': 0.016187929,
#   'gyro_z': 0.014660766,
#   'azimuth': 242.9444,
#   'pitch': -18.781696,
#   'roll': 17.40841,
#   'label': 'CHU',
#   'person_id': 45},
#  {'timestamp': 1339017530000,
#   'rel_time': 0.0,
#   'acc_x': -2.50955109935825,
#   'acc_y': -2.41314150143763,
#   'acc_z': 8.88684919394123,
#   'gyro_x': -0.035124753,
#   'gyro_y': 0.0036651916,
#   'gyro_z': 0.009162978,
#   'azimuth': 113.36582,
#   'pitch': 16.452131,
#   'roll': -17.527372,
#   'label': 'CHU',
#   'person_id': 1},
#  {'timestamp': 12818065468000,
#   'rel_time': 0.0,
#   'acc_x': 6.63319407027147,
#   'acc_y': 2.80805015215843,
#   'acc_z': 6.49660819283489,
#   'gyro_x': -0.03268129,
#   'gyro_y': 0.008552114,
#   'gyro_z': 0.01160644,
#   'azimuth': 289.38538,
#   'pitch': -53.364044,
#   'roll': 23.00299,
#   'label': 'CHU',
#   'person_id': 45},
#  {'timestamp': 3819654863000,
#   'rel_time': 0.0,
#   'acc_x': 4.07156851630235,
#   'acc_y': 6.14754225374695,
#   'acc_z': 6.23469882023602,
#   'gyro_x': 0.028710667,
#   'gyro_y': 0.029321533,
#   'gyro_z': 0.067500606,
#   'azimuth': 305.67136,
#   'pitch': -38.61917,
#   'roll': 29.40522,
#   'label': 'CHU',
#   'person_id': 3},
#  {'timestamp': 3902967046000,
#   'rel_time': 0.0,
#   'acc_x': 4.67778227041952,
#   'acc_y': 6.54944058977075,
#   'acc_z': 5.68026085027882,
#   'gyro_x': -0.027794369,
#   'gyro_y': 0.00030543262,
#   'gyro_z': -0.0027488936,
#   'azimuth': 272.761,
#   'pitch': -55.308655,
#   'roll': 24.666134,
#   'label': 'CHU',
#   'person_id': 3},
#  {'timestamp': 3842658207000,
#   'rel_time': 0.0,
#   'acc_x': 4.52821733908386,
#   'acc_y': 5.82592288816422,
#   'acc_z': 6.34771455675301,
#   'gyro_x': -0.05467244,
#   'gyro_y': 0.011911872,
#   'gyro_z': 0.022296581,
#   'azimuth': 283.82336,
#   'pitch': -57.64408,
#   'roll': 19.364603,
#   'label': 'CHU',
#   'person_id': 3},
#  {'timestamp': 3924221721000,
#   'rel_time': 0.0,
#   'acc_x': 4.45474129468206,
#   'acc_y': 6.65740703332752,
#   'acc_z': 5.41440628192074,
#   'gyro_x': -0.035124753,
#   'gyro_y': 0.008857546,
#   'gyro_z': 0.019547688,
#   'azimuth': 290.63837,
#   'pitch': -54.977123,
#   'roll': 24.591,
#   'label': 'CHU',
#   'person_id': 3},
#  {'timestamp': 12885169872000,
#   'rel_time': 0.0,
#   'acc_x': 6.30326678658998,
#   'acc_y': 3.69225398683215,
#   'acc_z': 6.3589997,
#   'gyro_x': -0.033292156,
#   'gyro_y': 0.0018325958,
#   'gyro_z': 0.015577064,
#   'azimuth': 295.8966,
#   'pitch': -50.009647,
#   'roll': 20.731314,
#   'label': 'CHU',
#   'person_id': 45},
#  {'timestamp': 4103166171000,
#   'rel_time': 0.0,
#   'acc_x': 4.15424005636478,
#   'acc_y': 8.56893681192643,
#   'acc_z': 2.66002199810642,
#   'gyro_x': 0.030848695,
#   'gyro_y': -0.03940081,
#   'gyro_z': -0.040927973,
#   'azimuth': 269.33606,
#   'pitch': -70.78989,
#   'roll': 17.15842,
#   'label': 'CHU',
#   'person_id': 6},
#  {'timestamp': 12795797256000,
#   'rel_time': 0.0,
#   'acc_x': 6.86648034857676,
#   'acc_y': 2.35585853943071,
#   'acc_z': 6.45536270014643,
#   'gyro_x': -0.028710667,
#   'gyro_y': 0.01160644,
#   'gyro_z': 0.022907447,
#   'azimuth': 294.2406,
#   'pitch': -12.297518,
#   'roll': 44.250984,
#   'label': 'CHU',
#   'person_id': 45},
#  {'timestamp': 1400082581000,
#   'rel_time': 0.0,
#   'acc_x': -2.15258680423315,
#   'acc_y': -0.433471451588703,
#   'acc_z': 9.33663637838809,
#   'gyro_x': -0.12492194,
#   'gyro_y': 0.05222898,
#   'gyro_z': 0.04734206,
#   'azimuth': 92.88115,
#   'pitch': 6.8881373,
#   'roll': -17.271826,
#   'label': 'CHU',
#   'person_id': 1},
#  {'timestamp': 2228641960000,
#   'rel_time': 0.0,
#   'acc_x': 3.63876358996171,
#   'acc_y': 7.92072401673049,
#   'acc_z': 4.40926786026671,
#   'gyro_x': 0.03145956,
#   'gyro_y': -0.018936822,
#   'gyro_z': 0.014049901,
#   'azimuth': 260.68173,
#   'pitch': -67.90942,
#   'roll': 13.829763,
#   'label': 'CHU',
#   'person_id': 5},
#  {'timestamp': 77671334628000,
#   'rel_time': 0.0,
#   'acc_x': 1.33295411987331,
#   'acc_y': 1.25704393261261,
#   'acc_z': 9.36822979005635,
#   'gyro_x': -0.04184427,
#   'gyro_y': -0.002443461,
#   'gyro_z': 0.017104227,
#   'azimuth': 282.91284,
#   'pitch': -45.532127,
#   'roll': -6.715706,
#   'label': 'CHU',
#   'person_id': 2},
#  {'timestamp': 19842188940000,
#   'rel_time': 0.0,
#   'acc_x': 7.02907141940225,
#   'acc_y': 1.27680595108859,
#   'acc_z': 6.58899515802591,
#   'gyro_x': -0.03848451,
#   'gyro_y': 0.02076942,
#   'gyro_z': 0.020158553,
#   'azimuth': 277.47525,
#   'pitch': -44.148663,
#   'roll': 24.940224,
#   'label': 'CHU',
#   'person_id': 12},
#  {'timestamp': 1525416394000,
#   'rel_time': 0.0,
#   'acc_x': 1.22198130947557,
#   'acc_y': 9.39268922487986,
#   'acc_z': 2.4762610621367,
#   'gyro_x': -0.028099801,
#   'gyro_y': 0.008857546,
#   'gyro_z': 0.018020526,
#   'azimuth': 293.78723,
#   'pitch': -71.77286,
#   'roll': 8.510558,
#   'label': 'CHU',
#   'person_id': 5},
#  {'timestamp': 19927525174000,
#   'rel_time': 0.0,
#   'acc_x': 7.13920836293064,
#   'acc_y': 1.25097204965549,
#   'acc_z': 6.36438417551677,
#   'gyro_x': -0.016798794,
#   'gyro_y': 0.0076358155,
#   'gyro_z': -0.0061086523,
#   'azimuth': 311.6136,
#   'pitch': -27.953432,
#   'roll': 35.904224,
#   'label': 'CHU',
#   'person_id': 12},
#  {'timestamp': 77772836743000,
#   'rel_time': 0.0,
#   'acc_x': 1.69249579712339,
#   'acc_y': 1.40345883758516,
#   'acc_z': 9.356541,
#   'gyro_x': -0.02321288,
#   'gyro_y': -0.00061086525,
#   'gyro_z': 0.0143553335,
#   'azimuth': 270.69913,
#   'pitch': -45.17949,
#   'roll': 1.3936837,
#   'label': 'CHU',
#   'person_id': 2},
#  {'timestamp': 1405588478000,
#   'rel_time': 0.0,
#   'acc_x': 9.33699923312207,
#   'acc_y': 0.995793893080387,
#   'acc_z': 2.71512165244691,
#   'gyro_x': -0.019242255,
#   'gyro_y': 0.0070249503,
#   'gyro_z': 0.007330383,
#   'azimuth': 289.66574,
#   'pitch': -35.956654,
#   'roll': 51.71341,
#   'label': 'CHU',
#   'person_id': 20},
#  {'timestamp': 1309096401000,
#   'rel_time': 0.0,
#   'acc_x': 7.86091030687315,
#   'acc_y': 0.752889744326194,
#   'acc_z': 5.53355520196376,
#   'gyro_x': -0.016187929,
#   'gyro_y': 0.019242255,
#   'gyro_z': 0.0125227375,
#   'azimuth': 290.56805,
#   'pitch': -19.481546,
#   'roll': 51.58029,
#   'label': 'CHU',
#   'person_id': 20},
#  {'timestamp': 1381689606000,
#   'rel_time': 0.0,
#   'acc_x': 8.38070472958636,
#   'acc_y': 0.318032039544722,
#   'acc_z': 4.94063359127048,
#   'gyro_x': -0.0070249503,
#   'gyro_y': 0.002443461,
#   'gyro_z': 0.014049901,
#   'azimuth': 285.966966567478,
#   'pitch': -24.4673996952209,
#   'roll': 52.2902883408476,
#   'label': 'CHU',
#   'person_id': 20},
#  {'timestamp': 1284173590000,
#   'rel_time': 0.0,
#   'acc_x': 7.61096969324674,
#   'acc_y': 1.18612715648842,
#   'acc_z': 5.85801013270695,
#   'gyro_x': -0.028710667,
#   'gyro_y': -0.04642576,
#   'gyro_z': -0.0021380284,
#   'azimuth': 278.72086,
#   'pitch': -5.219276,
#   'roll': 47.440624,
#   'label': 'CHU',
#   'person_id': 20},
#  {'timestamp': 2253115459000,
#   'rel_time': 0.0,
#   'acc_x': 3.32797509026758,
#   'acc_y': 8.56662719952936,
#   'acc_z': 3.41878144037651,
#   'gyro_x': -0.034208454,
#   'gyro_y': -0.014966198,
#   'gyro_z': 0.022602014,
#   'azimuth': 258.0522,
#   'pitch': -69.35858,
#   'roll': 14.006684,
#   'label': 'CHU',
#   'person_id': 5},
#  {'timestamp': 19821458878000,
#   'rel_time': 0.0,
#   'acc_x': 5.57292845398613,
#   'acc_y': 1.14779996250291,
#   'acc_z': 8.02562136780379,
#   'gyro_x': -0.022296581,
#   'gyro_y': -0.025961773,
#   'gyro_z': -0.0571159,
#   'azimuth': 299.93964,
#   'pitch': -2.8312953,
#   'roll': 32.79835,
#   'label': 'CHU',
#   'person_id': 12},
#  {'timestamp': 77651078494000,
#   'rel_time': 0.0,
#   'acc_x': 2.03557965514602,
#   'acc_y': 1.44508131736153,
#   'acc_z': 9.22409612789527,
#   'gyro_x': -0.021380283,
#   'gyro_y': 0.014049901,
#   'gyro_z': 0.01863139,
#   'azimuth': 188.5817,
#   'pitch': 13.180033,
#   'roll': 3.8985722,
#   'label': 'CHU',
#   'person_id': 2},
#  {'timestamp': 1554202205000,
#   'rel_time': 0.0,
#   'acc_x': 1.57160753119557,
#   'acc_y': 9.69535742324333,
#   'acc_z': 0.717249281433814,
#   'gyro_x': -0.05009095,
#   'gyro_y': 0.032375857,
#   'gyro_z': 0.044898596,
#   'azimuth': 265.30463,
#   'pitch': -85.06365,
#   'roll': 0.11631309,
#   'label': 'CHU',
#   'person_id': 5},
#  {'timestamp': 77751720814000,
#   'rel_time': 0.0,
#   'acc_x': 1.45029563535861,
#   'acc_y': 1.27556522893396,
#   'acc_z': 9.16904557588857,
#   'gyro_x': -0.033292156,
#   'gyro_y': 0.0036651916,
#   'gyro_z': 0.01740966,
#   'azimuth': 269.47574,
#   'pitch': -48.762337,
#   'roll': 5.530543,
#   'label': 'CHU',
#   'person_id': 2},
#  {'timestamp': 19908054928000,
#   'rel_time': 0.0,
#   'acc_x': 7.21242178459696,
#   'acc_y': 1.13855391540304,
#   'acc_z': 6.38753222728658,
#   'gyro_x': -0.039095376,
#   'gyro_y': 0.017104227,
#   'gyro_z': 0.016493361,
#   'azimuth': 294.9418,
#   'pitch': -44.37246,
#   'roll': 21.188484,
#   'label': 'CHU',
#   'person_id': 12},
#  {'timestamp': 1358087452000,
#   'rel_time': 0.0,
#   'acc_x': 7.97490571480619,
#   'acc_y': 0.541449662868131,
#   'acc_z': 5.41604440910839,
#   'gyro_x': -0.03268129,
#   'gyro_y': 0.01160644,
#   'gyro_z': 0.0070249503,
#   'azimuth': 272.36523,
#   'pitch': -38.602512,
#   'roll': 41.33497,
#   'label': 'CHU',
#   'person_id': 20},
#  {'timestamp': 19886331711000,
#   'rel_time': 0.0,
#   'acc_x': 5.14206857406563,
#   'acc_y': 1.95312745925251,
#   'acc_z': 7.12219667274417,
#   'gyro_x': -0.04153884,
#   'gyro_y': 0.022602014,
#   'gyro_z': 0.02107485,
#   'azimuth': 283.9836,
#   'pitch': -40.45336,
#   'roll': 24.873646,
#   'label': 'CHU',
#   'person_id': 12},
#  {'timestamp': 77709851515000,
#   'rel_time': 0.0,
#   'acc_x': 1.49070224391513,
#   'acc_y': 1.31749994633271,
#   'acc_z': 9.42652715356035,
#   'gyro_x': -0.036651913,
#   'gyro_y': 0.0036651916,
#   'gyro_z': 0.0076358155,
#   'azimuth': 271.2831,
#   'pitch': -48.217148,
#   'roll': 3.7801607,
#   'label': 'CHU',
#   'person_id': 2},
#  {'timestamp': 2183455956000,
#   'rel_time': 0.0,
#   'acc_x': 4.45560548469671,
#   'acc_y': 7.77753904449119,
#   'acc_z': 4.05228525850814,
#   'gyro_x': -0.10323623,
#   'gyro_y': 0.07422013,
#   'gyro_z': 0.04153884,
#   'azimuth': 260.75424,
#   'pitch': -71.36524,
#   'roll': 11.545791,
#   'label': 'CHU',
#   'person_id': 5},
#  {'timestamp': 19864155071000,
#   'rel_time': 0.0,
#   'acc_x': 6.4988251272622,
#   'acc_y': 0.266875071758397,
#   'acc_z': 7.13599681092704,
#   'gyro_x': -0.027183503,
#   'gyro_y': 0.011301007,
#   'gyro_z': 0.018325957,
#   'azimuth': 303.9693,
#   'pitch': -33.555466,
#   'roll': 28.43144,
#   'label': 'CHU',
#   'person_id': 12},
#  {'timestamp': 77690723911000,
#   'rel_time': 0.0,
#   'acc_x': 0.839958406667323,
#   'acc_y': 1.28103343380891,
#   'acc_z': 9.57241469733346,
#   'gyro_x': -0.03756821,
#   'gyro_y': -0.0018325958,
#   'gyro_z': 0.008857546,
#   'azimuth': 272.109,
#   'pitch': -38.538788,
#   'roll': 0.47829804,
#   'label': 'CHU',
#   'person_id': 2},
#  {'timestamp': 2206058279000,
#   'rel_time': 0.0,
#   'acc_x': 3.83179478378824,
#   'acc_y': 8.2636411621176,
#   'acc_z': 3.66591516299894,
#   'gyro_x': 0.06383542,
#   'gyro_y': -0.04062254,
#   'gyro_z': 0.007941248,
#   'azimuth': 259.2845,
#   'pitch': -70.76843,
#   'roll': 13.456672,
#   'label': 'CHU',
#   'person_id': 5},
#  {'timestamp': 1333210384000,
#   'rel_time': 0.0,
#   'acc_x': 7.32778905743558,
#   'acc_y': 1.47770191320202,
#   'acc_z': 6.10617335641106,
#   'gyro_x': -0.023518313,
#   'gyro_y': -0.0030543262,
#   'gyro_z': 0.0106901415,
#   'azimuth': 278.07974,
#   'pitch': -34.265812,
#   'roll': 46.44238,
#   'label': 'CHU',
#   'person_id': 20},
#  {'timestamp': 3862981638000,
#   'rel_time': 0.0,
#   'acc_x': 3.74409071564418,
#   'acc_y': 7.15800227346626,
#   'acc_z': 5.72340502055183,
#   'gyro_x': -0.03268129,
#   'gyro_y': 0.011301007,
#   'gyro_z': 0.022907447,
#   'azimuth': 281.1731,
#   'pitch': -58.78313,
#   'roll': 18.754728,
#   'label': 'CHU',
#   'person_id': 3},
#  {'timestamp': 1461045972000,
#   'rel_time': 0.0,
#   'acc_x': -4.16183619620103,
#   'acc_y': -2.53675338765385,
#   'acc_z': 8.25238146860768,
#   'gyro_x': 0.0012217305,
#   'gyro_y': 0.020158553,
#   'gyro_z': -0.004886922,
#   'azimuth': 106.81778,
#   'pitch': 13.463421,
#   'roll': -17.35511,
#   'label': 'CHU',
#   'person_id': 1},
#  {'timestamp': 4084664485000,
#   'rel_time': 0.0,
#   'acc_x': 4.46007059451593,
#   'acc_y': 8.02949818903186,
#   'acc_z': 3.5393884567402,
#   'gyro_x': 0.04337143,
#   'gyro_y': -0.02321288,
#   'gyro_z': -0.0076358155,
#   'azimuth': 272.98694,
#   'pitch': -61.32316,
#   'roll': 21.211937,
#   'label': 'CHU',
#   'person_id': 6},
#  {'timestamp': 12861992160000,
#   'rel_time': 0.0,
#   'acc_x': 5.99931518469633,
#   'acc_y': 3.3434785064936,
#   'acc_z': 7.09446099594405,
#   'gyro_x': -0.032070424,
#   'gyro_y': 0.0061086523,
#   'gyro_z': 0.009468411,
#   'azimuth': 290.04163,
#   'pitch': -56.431072,
#   'roll': 19.797281,
#   'label': 'CHU',
#   'person_id': 45},
#  {'timestamp': 1181471182000,
#   'rel_time': 0.0,
#   'acc_x': -2.22763487400116,
#   'acc_y': -1.82723154199961,
#   'acc_z': 9.08645060393746,
#   'gyro_x': -0.03176499,
#   'gyro_y': 0.013744468,
#   'gyro_z': 0.014660766,
#   'azimuth': 91.43865,
#   'pitch': 9.165532,
#   'roll': -14.954477,
#   'label': 'CHU',
#   'person_id': 1},
#  {'timestamp': 4159431352000,
#   'rel_time': 0.0,
#   'acc_x': 4.04429965882465,
#   'acc_y': 8.42426627758815,
#   'acc_z': 3.04617126826755,
#   'gyro_x': -0.004276057,
#   'gyro_y': -0.028405234,
#   'gyro_z': 0.0106901415,
#   'azimuth': 263.93076,
#   'pitch': -70.16206,
#   'roll': 16.48388,
#   'label': 'CHU',
#   'person_id': 6},
#  {'timestamp': 12838450285000,
#   'rel_time': 0.0,
#   'acc_x': 6.00903266671325,
#   'acc_y': 2.57595040921415,
#   'acc_z': 7.18541661394402,
#   'gyro_x': -0.021991149,
#   'gyro_y': 0.009162978,
#   'gyro_z': 0.017104227,
#   'azimuth': 288.72046,
#   'pitch': -52.22383,
#   'roll': 21.996502,
#   'label': 'CHU',
#   'person_id': 45},
#  {'timestamp': 1517048107000,
#   'rel_time': 0.0,
#   'acc_x': -2.97859742680532,
#   'acc_y': -1.28093008108317,
#   'acc_z': 9.18271994804244,
#   'gyro_x': -0.03268129,
#   'gyro_y': -0.009773844,
#   'gyro_z': 0.0030543262,
#   'azimuth': 107.81638,
#   'pitch': 12.674222,
#   'roll': -21.575138,
#   'label': 'CHU',
#   'person_id': 1},
#  {'timestamp': 4066733118000,
#   'rel_time': 0.0,
#   'acc_x': 3.68173966697175,
#   'acc_y': 7.81833040748383,
#   'acc_z': 4.66083858808783,
#   'gyro_x': 0.0012217305,
#   'gyro_y': 0.007941248,
#   'gyro_z': 0.03940081,
#   'azimuth': 296.4263,
#   'pitch': -53.423874,
#   'roll': 20.252792,
#   'label': 'CHU',
#   'person_id': 6},
#  {'timestamp': 1277440881000,
#   'rel_time': 0.0,
#   'acc_x': -3.38929635161481,
#   'acc_y': -2.1913645567878,
#   'acc_z': 8.65398516823934,
#   'gyro_x': -0.042455133,
#   'gyro_y': 0.0036651916,
#   'gyro_z': 0.013439035,
#   'azimuth': 111.31371,
#   'pitch': 12.768585,
#   'roll': -15.637906,
#   'label': 'CHU',
#   'person_id': 1},
#  {'timestamp': 4140989034000,
#   'rel_time': 0.0,
#   'acc_x': 3.90197709465493,
#   'acc_y': 8.485051,
#   'acc_z': 3.25790090178169,
#   'gyro_x': 0.03023783,
#   'gyro_y': 0.06963864,
#   'gyro_z': -0.04642576,
#   'azimuth': 274.72446,
#   'pitch': -68.865776,
#   'roll': 15.660394,
#   'label': 'CHU',
#   'person_id': 6},
#  {'timestamp': 3883018896000,
#   'rel_time': 0.0,
#   'acc_x': 4.64964234363541,
#   'acc_y': 6.58415734363541,
#   'acc_z': 5.48709893190152,
#   'gyro_x': -0.03359759,
#   'gyro_y': 0.013744468,
#   'gyro_z': 0.02076942,
#   'azimuth': 300.38962,
#   'pitch': -49.89076,
#   'roll': 25.121435,
#   'label': 'CHU',
#   'person_id': 3},
#  {'timestamp': 8953736764000,
#   'rel_time': 0.0,
#   'acc_x': 1.9466047013787,
#   'acc_y': 9.69404025688473,
#   'acc_z': -0.870114769230423,
#   'gyro_x': -0.13530666,
#   'gyro_y': 0.35308012,
#   'gyro_z': 0.054061573,
#   'azimuth': 24.99816,
#   'pitch': -46.391384,
#   'roll': 33.726315,
#   'label': 'FOL',
#   'person_id': 38},
#  {'timestamp': 2513712050000,
#   'rel_time': 0.0,
#   'acc_x': -0.181558045207197,
#   'acc_y': 9.83834188452209,
#   'acc_z': -0.307043489691786,
#   'gyro_x': -9.274462,
#   'gyro_y': 0.70921457,
#   'gyro_z': -9.889603,
#   'azimuth': 224.19418,
#   'pitch': 9.479382,
#   'roll': -21.748268,
#   'label': 'FOL',
#   'person_id': 6},
#  {'timestamp': 1487121751000,
#   'rel_time': 0.0,
#   'acc_x': -0.720919313808623,
#   'acc_y': 9.15637653255999,
#   'acc_z': -3.87752162640645,
#   'gyro_x': -1.2351695,
#   'gyro_y': 0.7333437,
#   'gyro_z': 0.04886922,
#   'azimuth': 15.675225,
#   'pitch': -38.221977,
#   'roll': 14.968968,
#   'label': 'FOL',
#   'person_id': 11},
#  {'timestamp': 56032093217000,
#   'rel_time': 0.0,
#   'acc_x': 0.230103228167689,
#   'acc_y': 9.83977921128592,
#   'acc_z': -1.08761725690167,
#   'gyro_x': -0.028099801,
#   'gyro_y': -0.016493361,
#   'gyro_z': 0.021380283,
#   'azimuth': 64.29881,
#   'pitch': -17.48081,
#   'roll': 38.42027,
#   'label': 'FOL',
#   'person_id': 26},
#  {'timestamp': 2715108368000,
#   'rel_time': 0.0,
#   'acc_x': 1.91141189226133,
#   'acc_y': 9.28219735825453,
#   'acc_z': -2.9715716891116,
#   'gyro_x': -0.015882496,
#   'gyro_y': -0.011301007,
#   'gyro_z': 0.018325957,
#   'azimuth': 313.35333,
#   'pitch': -62.21154,
#   'roll': -12.251972,
#   'label': 'FOL',
#   'person_id': 42},
#  {'timestamp': 2845453406000,
#   'rel_time': 0.0,
#   'acc_x': 1.64444386543021,
#   'acc_y': 9.33185335975143,
#   'acc_z': -3.09586123479924,
#   'gyro_x': -0.043982297,
#   'gyro_y': -0.014966198,
#   'gyro_z': 0.013744468,
#   'azimuth': 319.09668,
#   'pitch': -59.72531,
#   'roll': -13.99159,
#   'label': 'FOL',
#   'person_id': 45},
#  {'timestamp': 1950493989000,
#   'rel_time': 0.0,
#   'acc_x': -0.19165676839242,
#   'acc_y': -9.66291757698043,
#   'acc_z': -1.33105556169156,
#   'gyro_x': 0.058643065,
#   'gyro_y': -0.042455133,
#   'gyro_z': -0.008246681,
#   'azimuth': 159.80028,
#   'pitch': 24.332554,
#   'roll': 48.372757,
#   'label': 'FOL',
#   'person_id': 1},
#  {'timestamp': 1671004904000,
#   'rel_time': 0.0,
#   'acc_x': -0.510780366201904,
#   'acc_y': 9.70266940616724,
#   'acc_z': -2.0470110099666,
#   'gyro_x': 0.0070249503,
#   'gyro_y': 0.06841691,
#   'gyro_z': -0.028405234,
#   'azimuth': 168.95337,
#   'pitch': -161.51419,
#   'roll': -22.940004,
#   'label': 'FOL',
#   'person_id': 21},
#  {'timestamp': 2798590100000,
#   'rel_time': 0.0,
#   'acc_x': -0.892734673541336,
#   'acc_y': 9.79276411698489,
#   'acc_z': -1.25080509359063,
#   'gyro_x': -0.029321533,
#   'gyro_y': -0.004886922,
#   'gyro_z': 0.0076358155,
#   'azimuth': 297.69022,
#   'pitch': -37.52055,
#   'roll': -45.52048,
#   'label': 'FOL',
#   'person_id': 35},
#  {'timestamp': 6405357797000,
#   'rel_time': 0.0,
#   'acc_x': 3.53815774364423,
#   'acc_y': 8.71583881073842,
#   'acc_z': -1.64757360592585,
#   'gyro_x': -0.18661933,
#   'gyro_y': -0.0888809,
#   'gyro_z': 0.028710667,
#   'azimuth': 327.23346,
#   'pitch': -56.33127,
#   'roll': 6.037024,
#   'label': 'FOL',
#   'person_id': 40},
#  {'timestamp': 1058292701000,
#   'rel_time': 0.0,
#   'acc_x': -2.23266975658389,
#   'acc_y': 9.70069429522532,
#   'acc_z': -2.1072989203716,
#   'gyro_x': -1.2528846,
#   'gyro_y': 0.93828905,
#   'gyro_z': -0.008857546,
#   'azimuth': 20.374554,
#   'pitch': -8.115744,
#   'roll': -43.421715,
#   'label': 'FOL',
#   'person_id': 4},
#  {'timestamp': 1056081791000,
#   'rel_time': 0.0,
#   'acc_x': -3.39962661915419,
#   'acc_y': 9.23237647881737,
#   'acc_z': 0.537615143570359,
#   'gyro_x': -0.6545421,
#   'gyro_y': 0.20189096,
#   'gyro_z': 0.056199603,
#   'azimuth': 103.86407,
#   'pitch': -159.56558,
#   'roll': 20.610153,
#   'label': 'FOL',
#   'person_id': 13},
#  {'timestamp': 5583252646000,
#   'rel_time': 0.0,
#   'acc_x': -0.0407559257942603,
#   'acc_y': 9.10521987773215,
#   'acc_z': 3.56659057872024,
#   'gyro_x': -1.1957687,
#   'gyro_y': 0.7626653,
#   'gyro_z': 0.037873644,
#   'azimuth': 28.924156,
#   'pitch': -32.432083,
#   'roll': 23.974558,
#   'label': 'FOL',
#   'person_id': 30},
#  {'timestamp': 317896479000,
#   'rel_time': 0.0,
#   'acc_x': -1.7812861,
#   'acc_y': 9.72262668414322,
#   'acc_z': 0.0034290350754475,
#   'gyro_x': -0.004581489,
#   'gyro_y': 0.011911872,
#   'gyro_z': 0.002443461,
#   'azimuth': 198.39046,
#   'pitch': -142.01521,
#   'roll': -36.07092,
#   'label': 'FOL',
#   'person_id': 14},
#  {'timestamp': 4508496466000,
#   'rel_time': 0.0,
#   'acc_x': 0.219493083889513,
#   'acc_y': 9.758766,
#   'acc_z': 1.46563813285333,
#   'gyro_x': -1.2592987,
#   'gyro_y': 0.73273283,
#   'gyro_z': 0.09101892,
#   'azimuth': 171.9761,
#   'pitch': -146.69391,
#   'roll': 30.414215,
#   'label': 'FOL',
#   'person_id': 29},
#  {'timestamp': 130298396129000,
#   'rel_time': 0.0,
#   'acc_x': -0.815252459228156,
#   'acc_y': 9.68762930841866,
#   'acc_z': 0.366511886904757,
#   'gyro_x': 0.043676864,
#   'gyro_y': -0.031154128,
#   'gyro_z': 0.062308256,
#   'azimuth': 212.72586,
#   'pitch': -124.41606,
#   'roll': 24.001299,
#   'label': 'FOL',
#   'person_id': 23},
#  {'timestamp': 13673339058000,
#   'rel_time': 0.0,
#   'acc_x': 1.99857785428423,
#   'acc_y': 9.59533578738243,
#   'acc_z': -1.52253512431054,
#   'gyro_x': -0.023518313,
#   'gyro_y': 0.046120327,
#   'gyro_z': 0.025961773,
#   'azimuth': 171.01372,
#   'pitch': -34.397167,
#   'roll': -29.037931,
#   'label': 'FOL',
#   'person_id': 37},
#  {'timestamp': 419803971000,
#   'rel_time': 0.0,
#   'acc_x': 1.13946268638987,
#   'acc_y': 9.65094743664398,
#   'acc_z': -2.20743626365751,
#   'gyro_x': -1.246776,
#   'gyro_y': 0.7486154,
#   'gyro_z': 0.058337633,
#   'azimuth': 0.0,
#   'pitch': 0.0,
#   'roll': -0.0,
#   'label': 'FOL',
#   'person_id': 9},
#  {'timestamp': 538751593000,
#   'rel_time': 0.0,
#   'acc_x': 2.99004361167243,
#   'acc_y': 9.10829932613257,
#   'acc_z': -2.3654714,
#   'gyro_x': -0.15149458,
#   'gyro_y': -0.052839845,
#   'gyro_z': -0.0033597588,
#   'azimuth': 345.18066,
#   'pitch': -28.596739,
#   'roll': -23.545414,
#   'label': 'FOL',
#   'person_id': 19},
#  {'timestamp': 5552500887000,
#   'rel_time': 0.0,
#   'acc_x': -0.620754690643522,
#   'acc_y': 9.52631639905506,
#   'acc_z': -2.90278617898531,
#   'gyro_x': -0.016187929,
#   'gyro_y': 0.012217305,
#   'gyro_z': 0.04550946,
#   'azimuth': 31.923082,
#   'pitch': -33.024475,
#   'roll': 29.27783,
#   'label': 'FOL',
#   'person_id': 30},
#  {'timestamp': 1092684987000,
#   'rel_time': 0.0,
#   'acc_x': -0.31590935911098,
#   'acc_y': 9.83543468245071,
#   'acc_z': 0.631979758021832,
#   'gyro_x': -1.1068878,
#   'gyro_y': 0.53023106,
#   'gyro_z': 0.11453723,
#   'azimuth': 74.249214,
#   'pitch': -146.90286,
#   'roll': 31.404175,
#   'label': 'FOL',
#   'person_id': 13},
#  {'timestamp': 481679579000,
#   'rel_time': 0.0,
#   'acc_x': -0.671695329911188,
#   'acc_y': 9.79680923780022,
#   'acc_z': -1.21361013893036,
#   'gyro_x': -0.65240407,
#   'gyro_y': 0.24007004,
#   'gyro_z': 0.057421334,
#   'azimuth': 290.8741,
#   'pitch': -15.393323,
#   'roll': -42.262424,
#   'label': 'FOL',
#   'person_id': 9},
#  {'timestamp': 13699131895000,
#   'rel_time': 0.0,
#   'acc_x': -0.860705003318512,
#   'acc_y': 9.84396073464892,
#   'acc_z': -2.19387373764594,
#   'gyro_x': -0.0030543262,
#   'gyro_y': -0.02321288,
#   'gyro_z': 0.059253927,
#   'azimuth': 134.70877,
#   'pitch': -37.53362,
#   'roll': -42.364967,
#   'label': 'FOL',
#   'person_id': 37},
#  {'timestamp': 4473716285000,
#   'rel_time': 0.0,
#   'acc_x': -0.400431815351515,
#   'acc_y': 9.816227,
#   'acc_z': 1.00644718623793,
#   'gyro_x': 0.009773844,
#   'gyro_y': 0.0009162979,
#   'gyro_z': -0.0030543262,
#   'azimuth': 162.42871,
#   'pitch': -137.20544,
#   'roll': 15.4982815,
#   'label': 'FOL',
#   'person_id': 29},
#  {'timestamp': 268313156000,
#   'rel_time': 0.0,
#   'acc_x': -1.2066777,
#   'acc_y': 9.69202229541556,
#   'acc_z': -1.54148890164415,
#   'gyro_x': -1.4795157,
#   'gyro_y': 0.7742717,
#   'gyro_z': 0.05467244,
#   'azimuth': 33.22559,
#   'pitch': -12.411732,
#   'roll': 41.291847,
#   'label': 'FOL',
#   'person_id': 3},
#  {'timestamp': 282578131000,
#   'rel_time': 0.0,
#   'acc_x': -2.02080481562163,
#   'acc_y': 9.67346253853522,
#   'acc_z': -0.355821095251247,
#   'gyro_x': -0.010995574,
#   'gyro_y': 0.02443461,
#   'gyro_z': -0.006414085,
#   'azimuth': 194.91219,
#   'pitch': -143.64758,
#   'roll': -30.65775,
#   'label': 'FOL',
#   'person_id': 14},
#  {'timestamp': 15258132787000,
#   'rel_time': 0.0,
#   'acc_x': -0.62155444047422,
#   'acc_y': 9.40158203668336,
#   'acc_z': -3.13393428523771,
#   'gyro_x': -0.03176499,
#   'gyro_y': 0.076358154,
#   'gyro_z': -0.039095376,
#   'azimuth': 331.82758,
#   'pitch': -51.714104,
#   'roll': -24.282305,
#   'label': 'FOL',
#   'person_id': 47},
#  {'timestamp': 2679121913000,
#   'rel_time': 0.0,
#   'acc_x': 2.77635485453964,
#   'acc_y': 9.2615291915834,
#   'acc_z': 0.934184267922815,
#   'gyro_x': 0.093462385,
#   'gyro_y': 0.22449298,
#   'gyro_z': -0.083383106,
#   'azimuth': 310.57486,
#   'pitch': -116.885956,
#   'roll': 4.4806886,
#   'label': 'FOL',
#   'person_id': 32},
#  {'timestamp': 56008206534000,
#   'rel_time': 0.0,
#   'acc_x': 0.293301846508468,
#   'acc_y': 9.85903232412449,
#   'acc_z': -0.486917739938552,
#   'gyro_x': -0.0106901415,
#   'gyro_y': 0.007330383,
#   'gyro_z': 0.005497787,
#   'azimuth': 48.06359,
#   'pitch': -18.081465,
#   'roll': 26.5335,
#   'label': 'FOL',
#   'person_id': 26},
#  {'timestamp': 2550651816000,
#   'rel_time': 0.0,
#   'acc_x': 1.02598842742047,
#   'acc_y': 9.701305,
#   'acc_z': -1.8195933,
#   'gyro_x': -1.2513574,
#   'gyro_y': 0.75869465,
#   'gyro_z': 0.07147124,
#   'azimuth': 25.602303,
#   'pitch': -16.74323,
#   'roll': 34.648678,
#   'label': 'FOL',
#   'person_id': 6},
#  {'timestamp': 8980598199000,
#   'rel_time': 0.0,
#   'acc_x': 1.99920889585455,
#   'acc_y': 9.60517400207792,
#   'acc_z': -0.600267796550649,
#   'gyro_x': -0.07544186,
#   'gyro_y': -0.008246681,
#   'gyro_z': 0.089491755,
#   'azimuth': 29.494976,
#   'pitch': -56.078453,
#   'roll': 28.51307,
#   'label': 'FOL',
#   'person_id': 38},
#  {'timestamp': 15025803023000,
#   'rel_time': 0.0,
#   'acc_x': -0.588594896535792,
#   'acc_y': 9.48638415224461,
#   'acc_z': -2.83651647818973,
#   'gyro_x': 0.01160644,
#   'gyro_y': 0.04337143,
#   'gyro_z': 0.032986723,
#   'azimuth': 327.8067,
#   'pitch': -55.040123,
#   'roll': -24.062275,
#   'label': 'FOL',
#   'person_id': 48},
#  {'timestamp': 2746666577000,
#   'rel_time': 0.0,
#   'acc_x': -0.37944806441373,
#   'acc_y': 9.42710729368925,
#   'acc_z': -3.26124601925094,
#   'gyro_x': -0.030543262,
#   'gyro_y': 0.06352998,
#   'gyro_z': -0.02687807,
#   'azimuth': 310.959,
#   'pitch': -60.58246,
#   'roll': -19.58348,
#   'label': 'FOL',
#   'person_id': 42},
#  {'timestamp': 2817927830000,
#   'rel_time': 0.0,
#   'acc_x': 2.59286530974358,
#   'acc_y': 8.6163386368334,
#   'acc_z': -3.54227483329669,
#   'gyro_x': -0.28955013,
#   'gyro_y': -0.54305923,
#   'gyro_z': 0.39767328,
#   'azimuth': 250.61998,
#   'pitch': -40.211533,
#   'roll': -49.78654,
#   'label': 'FOL',
#   'person_id': 45},
#  {'timestamp': 1703780640000,
#   'rel_time': 0.0,
#   'acc_x': 2.37534811934044,
#   'acc_y': 9.40423755016756,
#   'acc_z': -2.11673682976542,
#   'gyro_x': -1.2452488,
#   'gyro_y': 0.7761043,
#   'gyro_z': 0.057726767,
#   'azimuth': 62.363,
#   'pitch': -40.993496,
#   'roll': 9.106138,
#   'label': 'FOL',
#   'person_id': 21},
#  {'timestamp': 1913880519000,
#   'rel_time': 0.0,
#   'acc_x': 0.900010941791739,
#   'acc_y': -9.55762514514253,
#   'acc_z': -1.49346646870273,
#   'gyro_x': -0.17531833,
#   'gyro_y': -0.032986723,
#   'gyro_z': 0.0009162979,
#   'azimuth': 9.015643,
#   'pitch': 17.873316,
#   'roll': -41.67073,
#   'label': 'FOL',
#   'person_id': 1},
#  {'timestamp': 3406054770000,
#   'rel_time': 0.0,
#   'acc_x': 0.562402502543414,
#   'acc_y': 9.68402992535405,
#   'acc_z': 1.21756842177507,
#   'gyro_x': -0.032375857,
#   'gyro_y': -0.23732115,
#   'gyro_z': -0.0125227375,
#   'azimuth': 217.62703,
#   'pitch': -138.83098,
#   'roll': -25.469202,
#   'label': 'FOL',
#   'person_id': 16},
#  {'timestamp': 6357161341000,
#   'rel_time': 0.0,
#   'acc_x': 1.69476498306544,
#   'acc_y': 9.40438835295114,
#   'acc_z': 2.42318862398481,
#   'gyro_x': -0.7031059,
#   'gyro_y': 0.26267207,
#   'gyro_z': 0.05497787,
#   'azimuth': 0.40501866,
#   'pitch': -25.801577,
#   'roll': -17.156998,
#   'label': 'FOL',
#   'person_id': 31},
#  {'timestamp': 4771908100000,
#   'rel_time': 0.0,
#   'acc_x': -0.383263328094983,
#   'acc_y': 9.66242479744415,
#   'acc_z': -2.27896155339671,
#   'gyro_x': -0.024129177,
#   'gyro_y': 0.008552114,
#   'gyro_z': 0.011301007,
#   'azimuth': 44.554333,
#   'pitch': -24.841202,
#   'roll': 50.613377,
#   'label': 'FOL',
#   'person_id': 18},
#  {'timestamp': 52666764301000,
#   'rel_time': 0.0,
#   'acc_x': 1.34550063575788,
#   'acc_y': 9.68689922867568,
#   'acc_z': 0.581553529540399,
#   'gyro_x': -0.015271631,
#   'gyro_y': -0.019242255,
#   'gyro_z': 0.0018325958,
#   'azimuth': 39.766666,
#   'pitch': -6.141661,
#   'roll': 44.29274,
#   'label': 'FOL',
#   'person_id': 25},
#  {'timestamp': 2747090136000,
#   'rel_time': 0.0,
#   'acc_x': 1.57123639672818,
#   'acc_y': 9.49998816890796,
#   'acc_z': -2.55735295215034,
#   'gyro_x': -1.1979067,
#   'gyro_y': 0.754724,
#   'gyro_z': 0.032070424,
#   'azimuth': 169.88283,
#   'pitch': -155.29033,
#   'roll': 28.981276,
#   'label': 'FOL',
#   'person_id': 12},
#  {'timestamp': 2319601118000,
#   'rel_time': 0.0,
#   'acc_x': 7.52752038548424,
#   'acc_y': 6.23495215331491,
#   'acc_z': -2.17916780819523,
#   'gyro_x': -0.032375857,
#   'gyro_y': 0.024740042,
#   'gyro_z': -0.012217305,
#   'azimuth': 195.02615,
#   'pitch': -174.38481,
#   'roll': 47.789948,
#   'label': 'FOL',
#   'person_id': 46},
#  {'timestamp': 2570843536000,
#   'rel_time': 0.0,
#   'acc_x': 0.165632116319632,
#   'acc_y': 9.87651445534553,
#   'acc_z': 0.788124566319632,
#   'gyro_x': -0.041233405,
#   'gyro_y': 0.067500606,
#   'gyro_z': 0.007941248,
#   'azimuth': 109.399704,
#   'pitch': -39.046482,
#   'roll': -34.8791,
#   'label': 'FOL',
#   'person_id': 36},
#  {'timestamp': 1150287383000,
#   'rel_time': 0.0,
#   'acc_x': -0.41180268,
#   'acc_y': 9.73912497061216,
#   'acc_z': 0.459393912061541,
#   'gyro_x': -1.2247849,
#   'gyro_y': 0.7669413,
#   'gyro_z': 0.055283304,
#   'azimuth': 211.7687,
#   'pitch': -3.3653436,
#   'roll': 24.849915,
#   'label': 'FOL',
#   'person_id': 8},
#  {'timestamp': 3279591924000,
#   'rel_time': 0.0,
#   'acc_x': 2.06163788519437,
#   'acc_y': 9.39569932701768,
#   'acc_z': -1.03924820353798,
#   'gyro_x': -0.052534413,
#   'gyro_y': 0.012217305,
#   'gyro_z': 0.0030543262,
#   'azimuth': 325.69965,
#   'pitch': -15.537461,
#   'roll': 42.784477,
#   'label': 'FOL',
#   'person_id': 28},
#  {'timestamp': 211859631000,
#   'rel_time': 0.0,
#   'acc_x': -0.129279417020289,
#   'acc_y': 9.98588182637534,
#   'acc_z': -0.336567023031604,
#   'gyro_x': -1.1756102,
#   'gyro_y': 0.7669413,
#   'gyro_z': 0.031154128,
#   'azimuth': 20.54466,
#   'pitch': -17.830381,
#   'roll': 25.575535,
#   'label': 'FOL',
#   'person_id': 2},
#  {'timestamp': 2112466041000,
#   'rel_time': 0.0,
#   'acc_x': -4.98825266752068,
#   'acc_y': -8.20912125332543,
#   'acc_z': -0.904985132842273,
#   'gyro_x': -0.09040806,
#   'gyro_y': 0.047647487,
#   'gyro_z': 0.04520403,
#   'azimuth': 55.841045,
#   'pitch': 161.10841,
#   'roll': -59.574055,
#   'label': 'FOL',
#   'person_id': 15},
#  {'timestamp': 2672792934000,
#   'rel_time': 0.0,
#   'acc_x': -1.86894843811042,
#   'acc_y': 9.51823584527604,
#   'acc_z': -2.18756483094479,
#   'gyro_x': 0.02443461,
#   'gyro_y': -0.026267206,
#   'gyro_z': 0.038179077,
#   'azimuth': 126.661896,
#   'pitch': -48.36657,
#   'roll': -20.344372,
#   'label': 'FOL',
#   'person_id': 49},
#  {'timestamp': 9265296991000,
#   'rel_time': 0.0,
#   'acc_x': 2.50437908053626,
#   'acc_y': 9.42497160303177,
#   'acc_z': -1.88058173857701,
#   'gyro_x': -0.049785517,
#   'gyro_y': 0.0033597588,
#   'gyro_z': 0.01038471,
#   'azimuth': 48.821156,
#   'pitch': -35.65027,
#   'roll': 50.387096,
#   'label': 'FOL',
#   'person_id': 43},
#  {'timestamp': 1018250071000,
#   'rel_time': 0.0,
#   'acc_x': 2.97884142397162,
#   'acc_y': 9.55638755128788,
#   'acc_z': -0.101513217989026,
#   'gyro_x': 0.13072516,
#   'gyro_y': 0.049785517,
#   'gyro_z': -0.082161374,
#   'azimuth': 118.62032,
#   'pitch': -138.24234,
#   'roll': 44.771206,
#   'label': 'FOL',
#   'person_id': 33},
#  {'timestamp': 2071012259000,
#   'rel_time': 0.0,
#   'acc_x': 1.22405823736848,
#   'acc_y': 8.42372168304374,
#   'acc_z': 0.533064955170761,
#   'gyro_x': -0.01740966,
#   'gyro_y': -0.00061086525,
#   'gyro_z': -0.0015271631,
#   'azimuth': 257.32208,
#   'pitch': -51.573357,
#   'roll': -36.628567,
#   'label': 'FOL',
#   'person_id': 27},
#  {'timestamp': 1995457754000,
#   'rel_time': 0.0,
#   'acc_x': -0.92277782522682,
#   'acc_y': 9.63800589732092,
#   'acc_z': -1.97703789239527,
#   'gyro_x': -0.004581489,
#   'gyro_y': -0.062002823,
#   'gyro_z': 0.020158553,
#   'azimuth': 97.59335,
#   'pitch': -40.35349,
#   'roll': -42.633854,
#   'label': 'FOL',
#   'person_id': 39},
#  {'timestamp': 169915882000,
#   'rel_time': 0.0,
#   'acc_x': 2.03591369241166,
#   'acc_y': 9.57454543000579,
#   'acc_z': -1.99029121517668,
#   'gyro_x': -0.010079277,
#   'gyro_y': -0.0021380284,
#   'gyro_z': 0.00030543262,
#   'azimuth': 355.3182,
#   'pitch': -32.36965,
#   'roll': 16.135609,
#   'label': 'FOL',
#   'person_id': 7},
#  {'timestamp': 2437284971000,
#   'rel_time': 0.0,
#   'acc_x': 0.395817240522918,
#   'acc_y': 9.49232851813833,
#   'acc_z': -2.20120995779423,
#   'gyro_x': 0.04734206,
#   'gyro_y': -0.10567969,
#   'gyro_z': 0.07422013,
#   'azimuth': 10.3898535,
#   'pitch': -28.84194,
#   'roll': -11.020367,
#   'label': 'FOL',
#   'person_id': 20},
#  {'timestamp': 1169404107000,
#   'rel_time': 0.0,
#   'acc_x': -0.315805176522259,
#   'acc_y': 9.75882857675916,
#   'acc_z': -1.3796858551769,
#   'gyro_x': -0.029932396,
#   'gyro_y': 0.029321533,
#   'gyro_z': 0.016187929,
#   'azimuth': 333.31577,
#   'pitch': -38.324814,
#   'roll': -33.14999,
#   'label': 'FOL',
#   'person_id': 17},
#  {'timestamp': 17749189121000,
#   'rel_time': 0.0,
#   'acc_x': 0.29296442076529,
#   'acc_y': 9.72526037161116,
#   'acc_z': -2.0785964166219,
#   'gyro_x': -0.057421334,
#   'gyro_y': -0.055283304,
#   'gyro_z': 0.00030543262,
#   'azimuth': 315.0158,
#   'pitch': -51.37405,
#   'roll': -26.97497,
#   'label': 'FOL',
#   'person_id': 44},
#  {'timestamp': 9234385205000,
#   'rel_time': 0.0,
#   'acc_x': -0.415788120952651,
#   'acc_y': 9.71594928549154,
#   'acc_z': -2.02635177396897,
#   'gyro_x': -0.039095376,
#   'gyro_y': 0.0036651916,
#   'gyro_z': 0.037873644,
#   'azimuth': 203.42445,
#   'pitch': -144.04391,
#   'roll': -31.780573,
#   'label': 'FOL',
#   'person_id': 43},
#  {'timestamp': 138692441000,
#   'rel_time': 0.0,
#   'acc_x': 4.15560831642343,
#   'acc_y': 8.69670857192783,
#   'acc_z': -2.26889678669236,
#   'gyro_x': -1.0900891,
#   'gyro_y': 0.5039638,
#   'gyro_z': 0.11362094,
#   'azimuth': 357.5437,
#   'pitch': -25.575428,
#   'roll': 24.053415,
#   'label': 'FOL',
#   'person_id': 7},
#  {'timestamp': 883802556000,
#   'rel_time': 0.0,
#   'acc_x': 0.413216812232314,
#   'acc_y': 9.68700225218093,
#   'acc_z': -0.823737553097514,
#   'gyro_x': -0.92149025,
#   'gyro_y': 0.4361578,
#   'gyro_z': 0.056199603,
#   'azimuth': 358.16373,
#   'pitch': -12.436004,
#   'roll': -45.50776,
#   'label': 'FOL',
#   'person_id': 10},
#  {'timestamp': 1966283562000,
#   'rel_time': 0.0,
#   'acc_x': 0.518725518475854,
#   'acc_y': 9.86037632621985,
#   'acc_z': -0.899131552031158,
#   'gyro_x': -0.04917465,
#   'gyro_y': 0.04428773,
#   'gyro_z': -0.065973446,
#   'azimuth': 136.56148,
#   'pitch': -107.28723,
#   'roll': 12.338882,
#   'label': 'FOL',
#   'person_id': 39},
#  {'timestamp': 2105452434000,
#   'rel_time': 0.0,
#   'acc_x': 2.75775105771493,
#   'acc_y': 8.55947384570138,
#   'acc_z': 0.199931363854972,
#   'gyro_x': 0.09865474,
#   'gyro_y': -0.08582657,
#   'gyro_z': 0.01160644,
#   'azimuth': 161.23892,
#   'pitch': -126.8697,
#   'roll': -3.2712164,
#   'label': 'FOL',
#   'person_id': 27},
#  {'timestamp': 2406475969000,
#   'rel_time': 0.0,
#   'acc_x': -1.59265433326035,
#   'acc_y': 9.40359514583333,
#   'acc_z': -1.32408890617702,
#   'gyro_x': -1.2666291,
#   'gyro_y': 0.60903263,
#   'gyro_z': 0.24098633,
#   'azimuth': 13.419505,
#   'pitch': -26.440516,
#   'roll': -8.79812,
#   'label': 'FOL',
#   'person_id': 20},
#  {'timestamp': 3411132429000,
#   'rel_time': 0.0,
#   'acc_x': 3.02285368351094,
#   'acc_y': 9.01076497445711,
#   'acc_z': 2.09231930886951,
#   'gyro_x': 0.17623462,
#   'gyro_y': 0.09773844,
#   'gyro_z': 0.14538592,
#   'azimuth': 29.0215,
#   'pitch': -58.215298,
#   'roll': 5.6167717,
#   'label': 'FOL',
#   'person_id': 34},
#  {'timestamp': 17782366528000,
#   'rel_time': 0.0,
#   'acc_x': 2.30215560356349,
#   'acc_y': 9.6362597181194,
#   'acc_z': -1.51335694018894,
#   'gyro_x': 0.004886922,
#   'gyro_y': -0.10476339,
#   'gyro_z': 0.04337143,
#   'azimuth': 306.09573,
#   'pitch': -52.131588,
#   'roll': -21.619839,
#   'label': 'FOL',
#   'person_id': 44},
#  {'timestamp': 1766795979000,
#   'rel_time': 0.0,
#   'acc_x': 0.266806822902294,
#   'acc_y': 9.86249846321715,
#   'acc_z': 1.0427969778167,
#   'gyro_x': 9.966877,
#   'gyro_y': -4.4269404,
#   'gyro_z': 5.2962017,
#   'azimuth': 33.847492,
#   'pitch': -11.335146,
#   'roll': 40.266937,
#   'label': 'FOL',
#   'person_id': 5},
#  {'timestamp': 2717661874000,
#   'rel_time': 0.0,
#   'acc_x': -2.86154240693288,
#   'acc_y': 9.17246582023639,
#   'acc_z': 2.56793002896192,
#   'gyro_x': -0.6743952,
#   'gyro_y': 0.27550024,
#   'gyro_z': 0.09254608,
#   'azimuth': 19.909225,
#   'pitch': -174.19783,
#   'roll': 29.772114,
#   'label': 'FOL',
#   'person_id': 12},
#  {'timestamp': 6392121759000,
#   'rel_time': 0.0,
#   'acc_x': 0.841956203779899,
#   'acc_y': 9.25139570298442,
#   'acc_z': 3.217807,
#   'gyro_x': -1.2443326,
#   'gyro_y': 0.7675522,
#   'gyro_z': 0.06291912,
#   'azimuth': 178.88162,
#   'pitch': -146.42139,
#   'roll': 25.631287,
#   'label': 'FOL',
#   'person_id': 31},
#  {'timestamp': 2144811162000,
#   'rel_time': 0.0,
#   'acc_x': 5.24871842790842,
#   'acc_y': -8.21627180569307,
#   'acc_z': 0.143023923483911,
#   'gyro_x': -1.251052,
#   'gyro_y': 0.73914695,
#   'gyro_z': 0.08674286,
#   'azimuth': 14.941541,
#   'pitch': 178.6814,
#   'roll': -18.630768,
#   'label': 'FOL',
#   'person_id': 15},
#  {'timestamp': 3310056761000,
#   'rel_time': 0.0,
#   'acc_x': 0.0757043657426198,
#   'acc_y': 9.41233987094001,
#   'acc_z': -2.71795136046825,
#   'gyro_x': -0.06841691,
#   'gyro_y': -0.020158553,
#   'gyro_z': -0.0015271631,
#   'azimuth': 254.61598,
#   'pitch': -47.87599,
#   'roll': -40.51095,
#   'label': 'FOL',
#   'person_id': 28},
#  {'timestamp': 46658305883000,
#   'rel_time': 0.0,
#   'acc_x': 4.43470134847924,
#   'acc_y': 9.10063982303992,
#   'acc_z': 1.00193011302121,
#   'gyro_x': 0.09285152,
#   'gyro_y': 0.020158553,
#   'gyro_z': 0.043066,
#   'azimuth': 266.31348,
#   'pitch': -156.05093,
#   'roll': 36.124966,
#   'label': 'FOL',
#   'person_id': 22},
#  {'timestamp': 1121265900000,
#   'rel_time': 0.0,
#   'acc_x': -0.687041810374024,
#   'acc_y': 9.90290352021451,
#   'acc_z': 0.421986399729479,
#   'gyro_x': -1.2641857,
#   'gyro_y': 0.6621779,
#   'gyro_z': 0.09712757,
#   'azimuth': -21.337055,
#   'pitch': -9.100451,
#   'roll': 55.339863,
#   'label': 'FOL',
#   'person_id': 8},
#  {'timestamp': 2546100224000,
#   'rel_time': 0.0,
#   'acc_x': 1.33100189711211,
#   'acc_y': 9.43259577941046,
#   'acc_z': 1.0343822729375,
#   'gyro_x': -0.043066,
#   'gyro_y': 0.01985312,
#   'gyro_z': 0.006414085,
#   'azimuth': 248.42465,
#   'pitch': -54.61208,
#   'roll': -14.193394,
#   'label': 'FOL',
#   'person_id': 36},
#  {'timestamp': 17814921100000,
#   'rel_time': 0.0,
#   'acc_x': 2.21407339310035,
#   'acc_y': 9.49019396550175,
#   'acc_z': -1.72424703449825,
#   'gyro_x': -0.04917465,
#   'gyro_y': -0.01985312,
#   'gyro_z': 0.021380283,
#   'azimuth': 295.09094,
#   'pitch': -57.950737,
#   'roll': -20.26761,
#   'label': 'FOL',
#   'person_id': 44},
#  {'timestamp': 3286787302000,
#   'rel_time': 0.0,
#   'acc_x': 2.44658874166342,
#   'acc_y': 9.32609792018089,
#   'acc_z': 2.33496536951906,
#   'gyro_x': 0.011911872,
#   'gyro_y': 0.058337633,
#   'gyro_z': 0.016798794,
#   'azimuth': 49.63441,
#   'pitch': -59.398434,
#   'roll': 0.65613425,
#   'label': 'FOL',
#   'person_id': 34},
#  {'timestamp': 1105159008000,
#   'rel_time': 0.0,
#   'acc_x': -2.54063523825136,
#   'acc_y': 9.64236150441289,
#   'acc_z': -1.30114774959055,
#   'gyro_x': -1.1685852,
#   'gyro_y': 0.74372846,
#   'gyro_z': 0.030543262,
#   'azimuth': 13.732328,
#   'pitch': -10.961986,
#   'roll': -34.875473,
#   'label': 'FOL',
#   'person_id': 17},
#  {'timestamp': 2142232592000,
#   'rel_time': 0.0,
#   'acc_x': 2.00460565247419,
#   'acc_y': 10.0621708837665,
#   'acc_z': 0.464266311899252,
#   'gyro_x': 0.12492194,
#   'gyro_y': -0.040927973,
#   'gyro_z': 0.043066,
#   'azimuth': 172.06302,
#   'pitch': -120.98571,
#   'roll': -6.08494,
#   'label': 'FOL',
#   'person_id': 27},
#  {'timestamp': 966369969000,
#   'rel_time': 0.0,
#   'acc_x': 1.05949713018642,
#   'acc_y': 9.67568323564396,
#   'acc_z': 0.520591756003298,
#   'gyro_x': -0.05589417,
#   'gyro_y': -0.16279559,
#   'gyro_z': 0.008857546,
#   'azimuth': 133.58322,
#   'pitch': -131.2319,
#   'roll': 32.77516,
#   'label': 'FOL',
#   'person_id': 33},
#  {'timestamp': 850877279000,
#   'rel_time': 0.0,
#   'acc_x': 0.706059931643836,
#   'acc_y': 9.53755524657534,
#   'acc_z': -1.44481224643836,
#   'gyro_x': -0.009162978,
#   'gyro_y': -0.02565634,
#   'gyro_z': -0.08368854,
#   'azimuth': 346.5138,
#   'pitch': -23.0916,
#   'roll': -40.391678,
#   'label': 'FOL',
#   'person_id': 10},
#  {'timestamp': 2615807040000,
#   'rel_time': 0.0,
#   'acc_x': 1.70637592715002,
#   'acc_y': 9.41776175792026,
#   'acc_z': -2.16024630286669,
#   'gyro_x': -0.063224554,
#   'gyro_y': -0.0015271631,
#   'gyro_z': 0.0842994,
#   'azimuth': 149.19542,
#   'pitch': -63.746227,
#   'roll': -5.9270267,
#   'label': 'FOL',
#   'person_id': 49},
#  {'timestamp': 46631468727000,
#   'rel_time': 0.0,
#   'acc_x': 3.55065841370309,
#   'acc_y': 9.32441089144904,
#   'acc_z': 0.722084525012424,
#   'gyro_x': 0.041233405,
#   'gyro_y': -0.03481932,
#   'gyro_z': 0.043982297,
#   'azimuth': 227.92668,
#   'pitch': -22.369667,
#   'roll': 15.309573,
#   'label': 'FOL',
#   'person_id': 22},
#  {'timestamp': 76160534000,
#   'rel_time': 0.0,
#   'acc_x': 1.77153355076847,
#   'acc_y': 9.82291684729797,
#   'acc_z': -0.407823829776896,
#   'gyro_x': 0.007941248,
#   'gyro_y': 0.033292156,
#   'gyro_z': -0.027183503,
#   'azimuth': 0.0,
#   'pitch': 0.0,
#   'roll': -0.0,
#   'label': 'FOL',
#   'person_id': 2},
#  {'timestamp': 2182217474000,
#   'rel_time': 0.0,
#   'acc_x': 1.43635104707235,
#   'acc_y': 9.74915501047925,
#   'acc_z': -0.861708656309361,
#   'gyro_x': -1.1612549,
#   'gyro_y': 0.7296785,
#   'gyro_z': 0.028099801,
#   'azimuth': 332.14044,
#   'pitch': 163.32753,
#   'roll': -20.502705,
#   'label': 'FOL',
#   'person_id': 15},
#  {'timestamp': 3363699403000,
#   'rel_time': 0.0,
#   'acc_x': 1.16863883668671,
#   'acc_y': 9.50005848375836,
#   'acc_z': -2.38696726261515,
#   'gyro_x': -0.21044308,
#   'gyro_y': 0.26389378,
#   'gyro_z': -0.069027774,
#   'azimuth': 241.1495,
#   'pitch': -125.907104,
#   'roll': 32.113827,
#   'label': 'FOL',
#   'person_id': 28},
#  {'timestamp': 2078907044000,
#   'rel_time': 0.0,
#   'acc_x': 7.13502000451722,
#   'acc_y': 7.43954423498548,
#   'acc_z': -2.42396949818112,
#   'gyro_x': -0.07880162,
#   'gyro_y': 0.0036651916,
#   'gyro_z': -0.040317107,
#   'azimuth': 170.03891,
#   'pitch': -164.57896,
#   'roll': 52.011475,
#   'label': 'FOL',
#   'person_id': 46},
#  {'timestamp': 52610321016000,
#   'rel_time': 0.0,
#   'acc_x': 1.88104705211881,
#   'acc_y': 9.41779178923673,
#   'acc_z': 0.67023106529289,
#   'gyro_x': -0.043982297,
#   'gyro_y': 0.049785517,
#   'gyro_z': 0.0009162979,
#   'azimuth': 25.448452,
#   'pitch': 18.439663,
#   'roll': -32.699898,
#   'label': 'FOL',
#   'person_id': 25},
#  {'timestamp': 6427725335000,
#   'rel_time': 0.0,
#   'acc_x': 1.80286295628619,
#   'acc_y': 9.20804138621401,
#   'acc_z': 2.818004306893,
#   'gyro_x': -0.0067195175,
#   'gyro_y': 0.01863139,
#   'gyro_z': 0.0018325958,
#   'azimuth': 165.49936,
#   'pitch': -130.27567,
#   'roll': 18.073078,
#   'label': 'FOL',
#   'person_id': 31},
#  {'timestamp': 4710688998000,
#   'rel_time': 0.0,
#   'acc_x': -0.0648357294151337,
#   'acc_y': 9.73083669362884,
#   'acc_z': -1.80921580010056,
#   'gyro_x': -0.26145032,
#   'gyro_y': -0.032070424,
#   'gyro_z': 0.004886922,
#   'azimuth': 61.58406,
#   'pitch': -102.80126,
#   'roll': -9.579606,
#   'label': 'FOL',
#   'person_id': 18},
#  {'timestamp': 1732711681000,
#   'rel_time': 0.0,
#   'acc_x': 0.527029287789127,
#   'acc_y': 9.883265,
#   'acc_z': 0.364101592800821,
#   'gyro_x': -1.180497,
#   'gyro_y': 0.76174897,
#   'gyro_z': 0.037873644,
#   'azimuth': 32.960583,
#   'pitch': -4.4281898,
#   'roll': 42.17931,
#   'label': 'FOL',
#   'person_id': 5},
#  {'timestamp': 178384830000,
#   'rel_time': 0.0,
#   'acc_x': 1.69571630581539,
#   'acc_y': 9.63510703046581,
#   'acc_z': 0.219489667604218,
#   'gyro_x': -1.1856894,
#   'gyro_y': 0.79168135,
#   'gyro_z': 0.06383542,
#   'azimuth': 19.414095,
#   'pitch': -20.903193,
#   'roll': 23.602013,
#   'label': 'FOL',
#   'person_id': 2},
#  {'timestamp': 1178548763000,
#   'rel_time': 0.0,
#   'acc_x': -0.947262944339342,
#   'acc_y': 9.76815188521319,
#   'acc_z': 0.507303179138814,
#   'gyro_x': -0.6588182,
#   'gyro_y': 0.24740042,
#   'gyro_z': 0.064751714,
#   'azimuth': 215.79778,
#   'pitch': -12.165791,
#   'roll': 19.867033,
#   'label': 'FOL',
#   'person_id': 8},
#  {'timestamp': 2595108797000,
#   'rel_time': 0.0,
#   'acc_x': 0.877474807250184,
#   'acc_y': 9.65025750898392,
#   'acc_z': 1.56144713744878,
#   'gyro_x': -0.035430185,
#   'gyro_y': 0.022296581,
#   'gyro_z': 0.017104227,
#   'azimuth': 136.14162,
#   'pitch': -26.56179,
#   'roll': -29.873564,
#   'label': 'FOL',
#   'person_id': 36},
#  {'timestamp': 46582821041000,
#   'rel_time': 0.0,
#   'acc_x': 2.55243986491148,
#   'acc_y': 9.26818726052656,
#   'acc_z': 1.12549574901385,
#   'gyro_x': 0.08307768,
#   'gyro_y': -0.027183503,
#   'gyro_z': 0.032986723,
#   'azimuth': 126.08774,
#   'pitch': -14.299492,
#   'roll': 36.58961,
#   'label': 'FOL',
#   'person_id': 22},
#  {'timestamp': 2290712062000,
#   'rel_time': 0.0,
#   'acc_x': 7.7563056852015,
#   'acc_y': 5.37410178079718,
#   'acc_z': -2.61799237365118,
#   'gyro_x': 0.15241088,
#   'gyro_y': 0.018325957,
#   'gyro_z': 0.073303826,
#   'azimuth': 138.69107,
#   'pitch': -140.00526,
#   'roll': 45.975437,
#   'label': 'FOL',
#   'person_id': 46},
#  {'timestamp': 1685731234000,
#   'rel_time': 0.0,
#   'acc_x': 0.643854505424348,
#   'acc_y': 10.4864905458738,
#   'acc_z': -0.0121301923286113,
#   'gyro_x': -0.30604348,
#   'gyro_y': -0.36346483,
#   'gyro_z': -0.14935656,
#   'azimuth': 148.05995,
#   'pitch': -20.61371,
#   'roll': -21.850235,
#   'label': 'FOL',
#   'person_id': 5},
#  {'timestamp': 2778980872000,
#   'rel_time': 0.0,
#   'acc_x': 2.67613202367631,
#   'acc_y': 9.183356447687,
#   'acc_z': -2.528277,
#   'gyro_x': -0.95569867,
#   'gyro_y': 0.3042109,
#   'gyro_z': 0.14446963,
#   'azimuth': 354.09595,
#   'pitch': -29.500818,
#   'roll': -15.3838415,
#   'label': 'FOL',
#   'person_id': 12},
#  {'timestamp': 4741302569000,
#   'rel_time': 0.0,
#   'acc_x': -1.21476362119526,
#   'acc_y': 9.91106320196326,
#   'acc_z': -1.62421599951413,
#   'gyro_x': -1.2681563,
#   'gyro_y': 0.67347896,
#   'gyro_z': 0.09468412,
#   'azimuth': 30.802124,
#   'pitch': -13.280961,
#   'roll': 46.7709,
#   'label': 'FOL',
#   'person_id': 18},
#  {'timestamp': 52641169565000,
#   'rel_time': 0.0,
#   'acc_x': 0.903430636599705,
#   'acc_y': 9.79866514299995,
#   'acc_z': 0.263915858723283,
#   'gyro_x': -0.057421334,
#   'gyro_y': 0.008857546,
#   'gyro_z': 0.004581489,
#   'azimuth': 73.00986,
#   'pitch': -44.44256,
#   'roll': 23.077354,
#   'label': 'FOL',
#   'person_id': 25},
#  {'timestamp': 1135129644000,
#   'rel_time': 0.0,
#   'acc_x': -1.01502587126175,
#   'acc_y': 9.72013524001586,
#   'acc_z': -1.79083977425235,
#   'gyro_x': 7.436979,
#   'gyro_y': 0.74097955,
#   'gyro_z': 0.035430185,
#   'azimuth': 9.270098,
#   'pitch': -16.161661,
#   'roll': -35.339848,
#   'label': 'FOL',
#   'person_id': 17},
#  {'timestamp': 3180325586000,
#   'rel_time': 0.0,
#   'acc_x': 3.04365980854494,
#   'acc_y': 8.56999102055618,
#   'acc_z': 2.18931957954265,
#   'gyro_x': 0.046120327,
#   'gyro_y': -0.048258353,
#   'gyro_z': 0.06261369,
#   'azimuth': 200.60248,
#   'pitch': -119.896484,
#   'roll': -9.845999,
#   'label': 'FOL',
#   'person_id': 34},
#  {'timestamp': 2465023617000,
#   'rel_time': 0.0,
#   'acc_x': -1.10076323716315,
#   'acc_y': 10.0428737405818,
#   'acc_z': -1.89441894943232,
#   'gyro_x': -1.2052372,
#   'gyro_y': 0.7287622,
#   'gyro_z': 0.034513887,
#   'azimuth': 11.046375,
#   'pitch': -17.603197,
#   'roll': -14.661506,
#   'label': 'FOL',
#   'person_id': 20},
#  {'timestamp': 219647909000,
#   'rel_time': 0.0,
#   'acc_x': 3.75372864278569,
#   'acc_y': 8.9830992179297,
#   'acc_z': -1.58640868790216,
#   'gyro_x': 0.04153884,
#   'gyro_y': 0.06963864,
#   'gyro_z': 0.02565634,
#   'azimuth': 356.4026,
#   'pitch': -33.58333,
#   'roll': 14.085696,
#   'label': 'FOL',
#   'person_id': 7},
#  {'timestamp': 750713034000,
#   'rel_time': 0.0,
#   'acc_x': 0.413343619660677,
#   'acc_y': 9.74914368206186,
#   'acc_z': -1.70385580801964,
#   'gyro_x': -0.027488936,
#   'gyro_y': -0.21624629,
#   'gyro_z': 0.077579886,
#   'azimuth': 214.30576,
#   'pitch': -134.07494,
#   'roll': -35.32144,
#   'label': 'FOL',
#   'person_id': 10},
#  {'timestamp': 2023298165000,
#   'rel_time': 0.0,
#   'acc_x': -0.0249540479534972,
#   'acc_y': 10.0576712612698,
#   'acc_z': -1.71285873242859,
#   'gyro_x': -0.122783914,
#   'gyro_y': -0.016798794,
#   'gyro_z': 0.056199603,
#   'azimuth': 128.93497,
#   'pitch': -71.10829,
#   'roll': -13.80719,
#   'label': 'FOL',
#   'person_id': 39},
#  {'timestamp': 992735624000,
#   'rel_time': 0.0,
#   'acc_x': 0.232137536358627,
#   'acc_y': 9.78721651250507,
#   'acc_z': 0.833686888896208,
#   'gyro_x': -0.2733622,
#   'gyro_y': -0.033292156,
# ...
#   'pitch': -37.993538,
#   'roll': 48.560596,
#   'label': 'SCH',
#   'person_id': 10},
#  {'timestamp': 1367128802000,
#   'rel_time': 0.0,
#   'acc_x': -0.0435427224579161,
#   'acc_y': -9.73057201001353,
#   'acc_z': -0.598282185926928,
#   'gyro_x': -0.02076942,
#   'gyro_y': 0.0076358155,
#   'gyro_z': 0.021685716,
#   'azimuth': 105.22867,
#   'pitch': 101.325424,
#   'roll': 9.987153,
#   'label': 'SCH',
#   'person_id': 1},
#  {'timestamp': 1279934729000,
#   'rel_time': 0.0,
#   'acc_x': -0.949063897982205,
#   'acc_y': 9.82541997987148,
#   'acc_z': -0.881322212862086,
#   'gyro_x': -0.03390302,
#   'gyro_y': 0.008246681,
#   'gyro_z': 0.01160644,
#   'azimuth': 343.8677,
#   'pitch': -104.575676,
#   'roll': 14.082769,
#   'label': 'SCH',
#   'person_id': 49},
#  {'timestamp': 3131463729000,
#   'rel_time': 0.0,
#   'acc_x': 3.65175349001705,
#   'acc_y': 9.08519832386078,
#   'acc_z': 0.18056483336444,
#   'gyro_x': -0.24373524,
#   'gyro_y': 0.05100725,
#   'gyro_z': 0.05955936,
#   'azimuth': 149.69862,
#   'pitch': 3.9546428,
#   'roll': 44.68053,
#   'label': 'SCH',
#   'person_id': 6},
#  {'timestamp': 2531183476000,
#   'rel_time': 0.0,
#   'acc_x': -1.64050199164564,
#   'acc_y': 9.71631033611812,
#   'acc_z': 0.582372630021056,
#   'gyro_x': 0.0027488936,
#   'gyro_y': -0.011911872,
#   'gyro_z': 0.0033597588,
#   'azimuth': 65.38282,
#   'pitch': -147.27672,
#   'roll': -44.12116,
#   'label': 'SCH',
#   'person_id': 34},
#  {'timestamp': 941684639000,
#   'rel_time': 0.0,
#   'acc_x': 1.16813164462681,
#   'acc_y': 9.8644235154172,
#   'acc_z': -0.837886063213785,
#   'gyro_x': -0.062002823,
#   'gyro_y': -0.183565,
#   'gyro_z': -0.04886922,
#   'azimuth': 94.37961,
#   'pitch': -28.965128,
#   'roll': -45.496635,
#   'label': 'SCH',
#   'person_id': 20},
#  {'timestamp': 3009834562000,
#   'rel_time': 0.0,
#   'acc_x': -0.718120176624093,
#   'acc_y': 9.60552296884486,
#   'acc_z': -2.29844753232733,
#   'gyro_x': -1.0931433,
#   'gyro_y': 0.7495316,
#   'gyro_z': 0.03726278,
#   'azimuth': 50.199673,
#   'pitch': -43.37141,
#   'roll': 40.117004,
#   'label': 'SCH',
#   'person_id': 10},
#  {'timestamp': 1515424688000,
#   'rel_time': 0.0,
#   'acc_x': -1.34959806664659,
#   'acc_y': 9.76112044918087,
#   'acc_z': -0.623955931623703,
#   'gyro_x': -0.06414085,
#   'gyro_y': -0.034208454,
#   'gyro_z': 0.016493361,
#   'azimuth': 71.67188,
#   'pitch': -52.028915,
#   'roll': -1.5255202,
#   'label': 'SCH',
#   'person_id': 39},
#  {'timestamp': 9378812688000,
#   'rel_time': 0.0,
#   'acc_x': 1.55886369337195,
#   'acc_y': 9.81251674002964,
#   'acc_z': -0.222422293971173,
#   'gyro_x': -0.005497787,
#   'gyro_y': 0.024740042,
#   'gyro_z': 0.0033597588,
#   'azimuth': 162.09325,
#   'pitch': -75.84364,
#   'roll': 13.8372135,
#   'label': 'SCH',
#   'person_id': 50},
#  {'timestamp': 1225063037000,
#   'rel_time': 0.0,
#   'acc_x': -2.8921957,
#   'acc_y': 9.35240165650639,
#   'acc_z': 1.20927427179928,
#   'gyro_x': -0.007330383,
#   'gyro_y': 0.048563786,
#   'gyro_z': 0.015271631,
#   'azimuth': 14.205072,
#   'pitch': -139.56697,
#   'roll': -9.1936455,
#   'label': 'SCH',
#   'person_id': 33},
#  {'timestamp': 18298510631000,
#   'rel_time': 0.0,
#   'acc_x': 0.395726772886307,
#   'acc_y': 9.835381,
#   'acc_z': -0.124839052361823,
#   'gyro_x': -0.06536258,
#   'gyro_y': 0.040317107,
#   'gyro_z': 0.043982297,
#   'azimuth': 80.02345,
#   'pitch': -49.60521,
#   'roll': 14.69003,
#   'label': 'SCH',
#   'person_id': 44},
#  {'timestamp': 7400975095000,
#   'rel_time': 0.0,
#   'acc_x': 3.24388280884208,
#   'acc_y': 9.3527815355436,
#   'acc_z': -1.06654630807952,
#   'gyro_x': -0.02565634,
#   'gyro_y': 0.099571034,
#   'gyro_z': 0.0067195175,
#   'azimuth': 230.57999,
#   'pitch': -45.095287,
#   'roll': 1.1860307,
#   'label': 'SCH',
#   'person_id': 43},
#  {'timestamp': 2452439542000,
#   'rel_time': 0.0,
#   'acc_x': -0.314115344860981,
#   'acc_y': 9.93181685442924,
#   'acc_z': 0.779397303408269,
#   'gyro_x': 0.110872045,
#   'gyro_y': -0.005497787,
#   'gyro_z': -0.025350908,
#   'azimuth': 31.906183,
#   'pitch': -162.37885,
#   'roll': -48.17715,
#   'label': 'SCH',
#   'person_id': 34},
#  {'timestamp': 1377913446000,
#   'rel_time': 0.0,
#   'acc_x': -1.00448744403997,
#   'acc_y': 9.87341866823697,
#   'acc_z': -0.829900144245539,
#   'gyro_x': -0.08155051,
#   'gyro_y': 0.0693332,
#   'gyro_z': 0.01038471,
#   'azimuth': 117.00083,
#   'pitch': -55.095264,
#   'roll': 17.127048,
#   'label': 'SCH',
#   'person_id': 49},
#  {'timestamp': 6827719114000,
#   'rel_time': 0.0,
#   'acc_x': 0.852234479236764,
#   'acc_y': 9.84498739683202,
#   'acc_z': 0.469293916228971,
#   'gyro_x': -1.2211196,
#   'gyro_y': 0.7984009,
#   'gyro_z': 0.043066,
#   'azimuth': 125.04667,
#   'pitch': -61.63407,
#   'roll': -25.771782,
#   'label': 'SCH',
#   'person_id': 4},
#  {'timestamp': 2342374369000,
#   'rel_time': 0.0,
#   'acc_x': -2.52035511339506,
#   'acc_y': 9.64796204265964,
#   'acc_z': -1.63718421290016,
#   'gyro_x': -0.004886922,
#   'gyro_y': -0.109650314,
#   'gyro_z': 0.008246681,
#   'azimuth': 246.51987,
#   'pitch': -57.84406,
#   'roll': -16.249098,
#   'label': 'SCH',
#   'person_id': 36},
#  {'timestamp': 48198237585000,
#   'rel_time': 0.0,
#   'acc_x': 2.13283099606821,
#   'acc_y': 9.70469496882807,
#   'acc_z': -0.370105561965896,
#   'gyro_x': -0.0015271631,
#   'gyro_y': 0.015882496,
#   'gyro_z': 0.0021380284,
#   'azimuth': 20.739113,
#   'pitch': -164.53723,
#   'roll': -0.5645195,
#   'label': 'SCH',
#   'person_id': 22},
#  {'timestamp': 2508612518000,
#   'rel_time': 0.0,
#   'acc_x': 1.9093677054958,
#   'acc_y': 9.68752658341483,
#   'acc_z': -0.783506622864268,
#   'gyro_x': -0.0027488936,
#   'gyro_y': 0.011911872,
#   'gyro_z': 0.020158553,
#   'azimuth': 99.51056,
#   'pitch': -57.049828,
#   'roll': 25.82631,
#   'label': 'SCH',
#   'person_id': 41},
#  {'timestamp': 5288545697000,
#   'rel_time': 0.0,
#   'acc_x': 0.309647725173349,
#   'acc_y': 9.883265,
#   'acc_z': -0.539484020693396,
#   'gyro_x': -0.021380283,
#   'gyro_y': 0.047647487,
#   'gyro_z': 0.007330383,
#   'azimuth': 102.28418,
#   'pitch': -115.81052,
#   'roll': -4.3795953,
#   'label': 'SCH',
#   'person_id': 46},
#  {'timestamp': 54445312348000,
#   'rel_time': 0.0,
#   'acc_x': 5.39008068553854,
#   'acc_y': 8.09546331336419,
#   'acc_z': 1.6544427204967,
#   'gyro_x': 0.065973446,
#   'gyro_y': 0.07452556,
#   'gyro_z': 0.008246681,
#   'azimuth': 117.04267,
#   'pitch': -70.81046,
#   'roll': 17.614119,
#   'label': 'SCH',
#   'person_id': 25},
#  {'timestamp': 2660626275000,
#   'rel_time': 0.0,
#   'acc_x': -1.54797670987005,
#   'acc_y': 9.77470029711068,
#   'acc_z': -0.169162884348917,
#   'gyro_x': -0.015271631,
#   'gyro_y': -0.014966198,
#   'gyro_z': 0.022296581,
#   'azimuth': 237.41678,
#   'pitch': -79.323395,
#   'roll': 3.4307911,
#   'label': 'SCH',
#   'person_id': 18},
#  {'timestamp': 2374643230000,
#   'rel_time': 0.0,
#   'acc_x': -0.260572801324568,
#   'acc_y': 9.97746183829226,
#   'acc_z': 0.277299036048887,
#   'gyro_x': -1.0146471,
#   'gyro_y': 0.45814893,
#   'gyro_z': 0.112704635,
#   'azimuth': 294.71417,
#   'pitch': -8.5725,
#   'roll': -11.645776,
#   'label': 'SCH',
#   'person_id': 3},
#  {'timestamp': 2616374963000,
#   'rel_time': 0.0,
#   'acc_x': 3.79089350412869,
#   'acc_y': 9.13779489587131,
#   'acc_z': -0.510310155110996,
#   'gyro_x': -0.076052725,
#   'gyro_y': 0.00030543262,
#   'gyro_z': 0.057421334,
#   'azimuth': 74.053635,
#   'pitch': -47.33587,
#   'roll': 33.03627,
#   'label': 'SCH',
#   'person_id': 41},
#  {'timestamp': 48105645270000,
#   'rel_time': 0.0,
#   'acc_x': -1.84348524868356,
#   'acc_y': 9.710882,
#   'acc_z': -0.542087315115866,
#   'gyro_x': -0.019547688,
#   'gyro_y': -0.0012217305,
#   'gyro_z': 0.0076358155,
#   'azimuth': 358.11377,
#   'pitch': -120.31983,
#   'roll': -6.6130376,
#   'label': 'SCH',
#   'person_id': 22},
#  {'timestamp': 6957807149000,
#   'rel_time': 0.0,
#   'acc_x': -0.24214151126202,
#   'acc_y': 9.90222361525215,
#   'acc_z': 0.162611339108583,
#   'gyro_x': 0.049480084,
#   'gyro_y': 0.031154128,
#   'gyro_z': 0.024740042,
#   'azimuth': 308.5719,
#   'pitch': -18.70505,
#   'roll': -30.880518,
#   'label': 'SCH',
#   'person_id': 4},
#  {'timestamp': 4572546625000,
#   'rel_time': 0.0,
#   'acc_x': -1.53338417538353,
#   'acc_y': 9.77792,
#   'acc_z': 0.030373175642125,
#   'gyro_x': -0.019547688,
#   'gyro_y': 0.06994407,
#   'gyro_z': 0.0070249503,
#   'azimuth': 242.6077,
#   'pitch': -47.478226,
#   'roll': 11.799328,
#   'label': 'SCH',
#   'person_id': 28},
#  {'timestamp': 1912042640000,
#   'rel_time': 0.0,
#   'acc_x': -0.924523360863332,
#   'acc_y': 9.79429561033661,
#   'acc_z': 0.3082082799997,
#   'gyro_x': -0.0061086523,
#   'gyro_y': 0.204029,
#   'gyro_z': -0.010079277,
#   'azimuth': 201.16873,
#   'pitch': -28.367672,
#   'roll': 20.380348,
#   'label': 'SCH',
#   'person_id': 12},
#  {'timestamp': 2304343260000,
#   'rel_time': 0.0,
#   'acc_x': -0.316600904074111,
#   'acc_y': 10.073809501429,
#   'acc_z': 0.296668663490687,
#   'gyro_x': -0.9828822,
#   'gyro_y': 0.50488013,
#   'gyro_z': 0.14019357,
#   'azimuth': 291.5241,
#   'pitch': -9.246447,
#   'roll': -14.609875,
#   'label': 'SCH',
#   'person_id': 3},
#  {'timestamp': 8612164126000,
#   'rel_time': 0.0,
#   'acc_x': 0.431435357931625,
#   'acc_y': 9.74923419411333,
#   'acc_z': -1.08224247175866,
#   'gyro_x': -0.24495697,
#   'gyro_y': -0.12767084,
#   'gyro_z': -0.012217305,
#   'azimuth': 298.31268,
#   'pitch': -27.59246,
#   'roll': -53.387306,
#   'label': 'SCH',
#   'person_id': 9},
#  {'timestamp': 2745235893000,
#   'rel_time': 0.0,
#   'acc_x': -2.05002568260105,
#   'acc_y': 9.66599396836555,
#   'acc_z': -0.439944025219684,
#   'gyro_x': 0.008857546,
#   'gyro_y': 0.0015271631,
#   'gyro_z': 0.011911872,
#   'azimuth': 209.20946,
#   'pitch': -54.630447,
#   'roll': 15.476883,
#   'label': 'SCH',
#   'person_id': 18},
#  {'timestamp': 54530648768000,
#   'rel_time': 0.0,
#   'acc_x': 1.37990839909252,
#   'acc_y': 9.75003730795029,
#   'acc_z': 0.29324223695798,
#   'gyro_x': -0.007941248,
#   'gyro_y': 0.00030543262,
#   'gyro_z': 0.002443461,
#   'azimuth': 156.55179,
#   'pitch': -11.738989,
#   'roll': 39.921085,
#   'label': 'SCH',
#   'person_id': 25},
#  {'timestamp': 5200583538000,
#   'rel_time': 0.0,
#   'acc_x': -0.280948854081833,
#   'acc_y': 9.90286902538024,
#   'acc_z': -0.534926820927032,
#   'gyro_x': -0.08674286,
#   'gyro_y': -0.36865717,
#   'gyro_z': 0.08857546,
#   'azimuth': 3.9971094,
#   'pitch': -94.598526,
#   'roll': 1.5670286,
#   'label': 'SCH',
#   'person_id': 46},
#  {'timestamp': 14510618141000,
#   'rel_time': 0.0,
#   'acc_x': -0.481300040102644,
#   'acc_y': 9.76563999927004,
#   'acc_z': -0.908571506371568,
#   'gyro_x': -0.024740042,
#   'gyro_y': 0.0009162979,
#   'gyro_z': 0.0015271631,
#   'azimuth': 312.59863,
#   'pitch': -45.093674,
#   'roll': -12.951261,
#   'label': 'SCH',
#   'person_id': 48},
#  {'timestamp': 42329964549000,
#   'rel_time': 0.0,
#   'acc_x': 2.15201895210933,
#   'acc_y': 9.60829970558527,
#   'acc_z': 1.04258307251931,
#   'gyro_x': -0.022602014,
#   'gyro_y': -0.0290161,
#   'gyro_z': 0.023823744,
#   'azimuth': 40.743248,
#   'pitch': -102.39096,
#   'roll': -9.720208,
#   'label': 'SCH',
#   'person_id': 16},
#  {'timestamp': 3638179026000,
#   'rel_time': 0.0,
#   'acc_x': 2.70146229880417,
#   'acc_y': 9.55749245365156,
#   'acc_z': -0.144776019164109,
#   'gyro_x': -1.239751,
#   'gyro_y': 0.7296785,
#   'gyro_z': 0.07574729,
#   'azimuth': 316.04034,
#   'pitch': -11.381607,
#   'roll': -6.0872593,
#   'label': 'SCH',
#   'person_id': 7},
#  {'timestamp': 2998188614000,
#   'rel_time': 0.0,
#   'acc_x': -0.574486001807713,
#   'acc_y': 9.86409739992473,
#   'acc_z': -1.006367088252,
#   'gyro_x': 0.0027488936,
#   'gyro_y': -0.00580322,
#   'gyro_z': -0.0015271631,
#   'azimuth': 219.62732,
#   'pitch': -35.15109,
#   'roll': 23.739317,
#   'label': 'SCH',
#   'person_id': 35},
#  {'timestamp': 57950514075000,
#   'rel_time': 0.0,
#   'acc_x': 2.49395210243843,
#   'acc_y': 9.57573224373262,
#   'acc_z': -0.757105066911426,
#   'gyro_x': -0.03634648,
#   'gyro_y': 0.021991149,
#   'gyro_z': 0.02443461,
#   'azimuth': 156.39691,
#   'pitch': -21.185349,
#   'roll': 25.68988,
#   'label': 'SCH',
#   'person_id': 26},
#  {'timestamp': 3888941324000,
#   'rel_time': 0.0,
#   'acc_x': 4.73960797741662,
#   'acc_y': 8.85831817084102,
#   'acc_z': -0.127037058792238,
#   'gyro_x': 0.009773844,
#   'gyro_y': 0.03359759,
#   'gyro_z': 0.006414085,
#   'azimuth': 299.08203,
#   'pitch': -69.96385,
#   'roll': 19.189255,
#   'label': 'SCH',
#   'person_id': 32},
#  {'timestamp': 2814253719000,
#   'rel_time': 0.0,
#   'acc_x': -1.36539671209878,
#   'acc_y': 9.75004937284228,
#   'acc_z': 0.911302281929269,
#   'gyro_x': -0.03634648,
#   'gyro_y': 0.10781772,
#   'gyro_z': 0.022907447,
#   'azimuth': 321.0064,
#   'pitch': -31.45169,
#   'roll': -28.280777,
#   'label': 'SCH',
#   'person_id': 11},
#  {'timestamp': 3306505792000,
#   'rel_time': 0.0,
#   'acc_x': -1.77012619460949,
#   'acc_y': 9.60936479046637,
#   'acc_z': -1.29698715347863,
#   'gyro_x': 0.16646078,
#   'gyro_y': 0.008857546,
#   'gyro_z': -0.022296581,
#   'azimuth': 93.92689,
#   'pitch': -58.150696,
#   'roll': 7.229138,
#   'label': 'SCH',
#   'person_id': 42},
#  {'timestamp': 2914816819000,
#   'rel_time': 0.0,
#   'acc_x': 0.277010753861258,
#   'acc_y': 9.94883147747716,
#   'acc_z': -0.811594748147422,
#   'gyro_x': -0.03176499,
#   'gyro_y': -0.01160644,
#   'gyro_z': 0.0018325958,
#   'azimuth': 224.30153,
#   'pitch': -29.88063,
#   'roll': 34.53624,
#   'label': 'SCH',
#   'person_id': 35},
#  {'timestamp': 42244691560000,
#   'rel_time': 0.0,
#   'acc_x': 3.8927439126423,
#   'acc_y': 9.10207022363691,
#   'acc_z': 0.70822896789245,
#   'gyro_x': -0.029932396,
#   'gyro_y': -0.056505036,
#   'gyro_z': 0.008552114,
#   'azimuth': 40.635822,
#   'pitch': -107.534134,
#   'roll': 16.55496,
#   'label': 'SCH',
#   'person_id': 16},
#  {'timestamp': 14604595343000,
#   'rel_time': 0.0,
#   'acc_x': 0.0249013220592193,
#   'acc_y': 9.85248124859151,
#   'acc_z': -1.03593730541372,
#   'gyro_x': -0.023518313,
#   'gyro_y': -0.008246681,
#   'gyro_z': 0.018936822,
#   'azimuth': 83.6538,
#   'pitch': -41.105743,
#   'roll': 20.69789,
#   'label': 'SCH',
#   'person_id': 48},
#  {'timestamp': 7219434785000,
#   'rel_time': 0.0,
#   'acc_x': -0.724661048501168,
#   'acc_y': 9.85014253972888,
#   'acc_z': 0.0789966466140901,
#   'gyro_x': -0.029626964,
#   'gyro_y': -0.048563786,
#   'gyro_z': 0.007330383,
#   'azimuth': 221.75127,
#   'pitch': -32.68445,
#   'roll': -8.032961,
#   'label': 'SCH',
#   'person_id': 38},
#  {'timestamp': 2920142254000,
#   'rel_time': 0.0,
#   'acc_x': -0.153662993765346,
#   'acc_y': 9.94056715227208,
#   'acc_z': 0.057658150854874,
#   'gyro_x': 3.4468071,
#   'gyro_y': 7.1663656,
#   'gyro_z': 6.125451,
#   'azimuth': 331.87518,
#   'pitch': -17.10253,
#   'roll': -27.608774,
#   'label': 'SCH',
#   'person_id': 11},
#  {'timestamp': 4059577817000,
#   'rel_time': 0.0,
#   'acc_x': 4.42948509235431,
#   'acc_y': 8.90185394014122,
#   'acc_z': 0.301598772302666,
#   'gyro_x': 0.009468411,
#   'gyro_y': -0.028099801,
#   'gyro_z': 0.00580322,
#   'azimuth': 16.07829,
#   'pitch': -122.85394,
#   'roll': 19.441723,
#   'label': 'SCH',
#   'person_id': 32},
#  {'timestamp': 2205811954000,
#   'rel_time': 0.0,
#   'acc_x': 3.37843863496207,
#   'acc_y': 9.30680530261069,
#   'acc_z': -0.741438923778444,
#   'gyro_x': -0.022602014,
#   'gyro_y': -0.024740042,
#   'gyro_z': 0.005192355,
#   'azimuth': 311.71826,
#   'pitch': -54.86808,
#   'roll': 28.526031,
#   'label': 'SCH',
#   'person_id': 45},
#  {'timestamp': 121862842885000,
#   'rel_time': 0.0,
#   'acc_x': -0.817773635112384,
#   'acc_y': 9.81900923463406,
#   'acc_z': 1.02493072432054,
#   'gyro_x': -0.0076358155,
#   'gyro_y': -0.017715093,
#   'gyro_z': 0.0018325958,
#   'azimuth': 4.5180264,
#   'pitch': -27.909138,
#   'roll': 20.53622,
#   'label': 'SCH',
#   'person_id': 24},
#  {'timestamp': 14410121205000,
#   'rel_time': 0.0,
#   'acc_x': 0.333501330353548,
#   'acc_y': 9.80467792425038,
#   'acc_z': 0.677700560599697,
#   'gyro_x': -0.026572637,
#   'gyro_y': -0.021991149,
#   'gyro_z': 0.007330383,
#   'azimuth': 52.133408,
#   'pitch': -42.64996,
#   'roll': 14.662525,
#   'label': 'SCH',
#   'person_id': 47},
#  {'timestamp': 4727825474000,
#   'rel_time': 0.0,
#   'acc_x': -0.588363105591541,
#   'acc_y': 9.87289523743463,
#   'acc_z': 0.367239936666234,
#   'gyro_x': -0.006414085,
#   'gyro_y': 0.032986723,
#   'gyro_z': -0.00030543262,
#   'azimuth': 42.9119,
#   'pitch': -79.208115,
#   'roll': -4.2424035,
#   'label': 'SCH',
#   'person_id': 19},
#  {'timestamp': 1735648709000,
#   'rel_time': 0.0,
#   'acc_x': -0.929248412406575,
#   'acc_y': 9.87371284735368,
#   'acc_z': -1.16884259012034,
#   'gyro_x': -1.1792754,
#   'gyro_y': 0.73731434,
#   'gyro_z': 0.029932396,
#   'azimuth': 323.43762,
#   'pitch': -17.127445,
#   'roll': 21.105064,
#   'label': 'SCH',
#   'person_id': 2},
#  ...]
